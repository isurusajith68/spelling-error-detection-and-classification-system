# %%
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 95          jump          jummp            Addition of Letters             4
# 94         train          trian                 Transpositions             5
# 416      package        pacakge                 Transpositions             7
# 311         wrap            rap                 Silent Letters             4
# 204       ballet          baley  Letter-Phoneme Correspondence             6
# 436        gnash           nash                 Silent Letters             5
# 106         hour            our                 Silent Letters             4
# 384       rhythm          rythm            Omission of Letters             6
# 296    pneumonia        numonia                 Silent Letters             9
# 150       velvet        velvett            Addition of Letters             6
# 254      rapport         raport                 Silent Letters             7
# 308       almond          almon            Omission of Letters             6
# 183       honest         honset                 Transpositions             6
# 140         spin          spinn            Addition of Letters             4
# 156        choir          kwire  Letter-Phoneme Correspondence             5
# 335          pen           ppen            Addition of Letters             3
# 314      physics         fiziks  Letter-Phoneme Correspondence             7
# 248       resign        reesign            Addition of Letters             6
# 385       ballet          baley  Letter-Phoneme Correspondence             6
# 21          ship            sip  Letter-Phoneme Correspondence             4
#
#      Difficulty_Level
# 95                  2
# 94                  2
# 416                 3
# 311                 2
# 204                 3
# 436                 2
# 106                 2
# 384                 3
# 296                 4
# 150                 3
# 254                 3
# 308                 3
# 183                 3
# 140                 2
# 156                 2
# 335                 1
# 314                 3
# 248                 3
# 385                 3
# 21                  2

# %%
class DataProcessor:
    def __init__(self, dataset_path):
        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)
        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())
        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))
        self._create_char_encoding()
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}
        self.max_difficulty = self.df['Difficulty_Level'].max()
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")

    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word
        edits = jellyfish.levenshtein_distance(word, correct_word)
        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)
        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)
        phoneme_mismatch_flag = jellyfish.metaphone(word) != jellyfish.metaphone(correct_word) and not transposition_flag
        silent_letter_flag = edits > 0 and jellyfish.soundex(word) == jellyfish.soundex(correct_word) and not omission_flag
        return np.array([edits, transposition_flag, omission_flag, addition_flag, phoneme_mismatch_flag, silent_letter_flag], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(6,))
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(512, return_sequences=True, dropout=0.2))(x)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.2))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=15, restore_best_weights=True),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()}
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])
        error_acc = np.mean([np.all(pred > 0.5) == true for pred, true in zip(error_preds, self.y_val_error)])
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}
            # print(f"Debug - Word: {word}, Error Probabilities: {error_proba[0]}")

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences if not correct else {'Correct': 1.0},
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/100
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 11/11 [==============================] - 19s 557ms/step - loss: 4.4131 - error_output_loss: 0.6861 - diff_output_loss: 3.7270 - error_output_accuracy: 0.1576 - diff_output_mae: 1.6480 - val_loss: 1.4563 - val_error_output_loss: 0.6388 - val_diff_output_loss: 0.8175 - val_error_output_accuracy: 0.1807 - val_diff_output_mae: 0.7973
# Epoch 2/100
# 11/11 [==============================] - 2s 142ms/step - loss: 1.0858 - error_output_loss: 0.5916 - diff_output_loss: 0.4941 - error_output_accuracy: 0.2030 - diff_output_mae: 0.5864 - val_loss: 0.7781 - val_error_output_loss: 0.5387 - val_diff_output_loss: 0.2395 - val_error_output_accuracy: 0.1928 - val_diff_output_mae: 0.4033
# Epoch 3/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.8103 - error_output_loss: 0.5192 - diff_output_loss: 0.2911 - error_output_accuracy: 0.3061 - diff_output_mae: 0.4357 - val_loss: 0.6967 - val_error_output_loss: 0.4907 - val_diff_output_loss: 0.2060 - val_error_output_accuracy: 0.4458 - val_diff_output_mae: 0.3611
# Epoch 4/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.7357 - error_output_loss: 0.4911 - diff_output_loss: 0.2445 - error_output_accuracy: 0.3758 - diff_output_mae: 0.3986 - val_loss: 0.6564 - val_error_output_loss: 0.4767 - val_diff_output_loss: 0.1797 - val_error_output_accuracy: 0.4337 - val_diff_output_mae: 0.3333
# Epoch 5/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.6987 - error_output_loss: 0.4875 - diff_output_loss: 0.2112 - error_output_accuracy: 0.3606 - diff_output_mae: 0.3661 - val_loss: 0.6376 - val_error_output_loss: 0.4737 - val_diff_output_loss: 0.1639 - val_error_output_accuracy: 0.4578 - val_diff_output_mae: 0.3221
# Epoch 6/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.6877 - error_output_loss: 0.4819 - diff_output_loss: 0.2058 - error_output_accuracy: 0.4242 - diff_output_mae: 0.3704 - val_loss: 0.6294 - val_error_output_loss: 0.4718 - val_diff_output_loss: 0.1576 - val_error_output_accuracy: 0.6386 - val_diff_output_mae: 0.3136
# Epoch 7/100
# 11/11 [==============================] - 2s 158ms/step - loss: 0.6435 - error_output_loss: 0.4777 - diff_output_loss: 0.1658 - error_output_accuracy: 0.4242 - diff_output_mae: 0.3327 - val_loss: 0.6059 - val_error_output_loss: 0.4676 - val_diff_output_loss: 0.1383 - val_error_output_accuracy: 0.5301 - val_diff_output_mae: 0.2996
# Epoch 8/100
# 11/11 [==============================] - 2s 143ms/step - loss: 0.6274 - error_output_loss: 0.4700 - diff_output_loss: 0.1574 - error_output_accuracy: 0.4364 - diff_output_mae: 0.3255 - val_loss: 0.5843 - val_error_output_loss: 0.4613 - val_diff_output_loss: 0.1229 - val_error_output_accuracy: 0.4578 - val_diff_output_mae: 0.2863
# Epoch 9/100
# 11/11 [==============================] - 2s 140ms/step - loss: 0.6079 - error_output_loss: 0.4729 - diff_output_loss: 0.1350 - error_output_accuracy: 0.4000 - diff_output_mae: 0.2947 - val_loss: 0.5647 - val_error_output_loss: 0.4577 - val_diff_output_loss: 0.1070 - val_error_output_accuracy: 0.5060 - val_diff_output_mae: 0.2702
# Epoch 10/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.5911 - error_output_loss: 0.4660 - diff_output_loss: 0.1251 - error_output_accuracy: 0.4333 - diff_output_mae: 0.2824 - val_loss: 0.5519 - val_error_output_loss: 0.4545 - val_diff_output_loss: 0.0973 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2584
# Epoch 11/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.6084 - error_output_loss: 0.4622 - diff_output_loss: 0.1462 - error_output_accuracy: 0.4667 - diff_output_mae: 0.3042 - val_loss: 0.5424 - val_error_output_loss: 0.4491 - val_diff_output_loss: 0.0933 - val_error_output_accuracy: 0.4940 - val_diff_output_mae: 0.2565
# Epoch 12/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.5763 - error_output_loss: 0.4518 - diff_output_loss: 0.1245 - error_output_accuracy: 0.5061 - diff_output_mae: 0.2889 - val_loss: 0.5371 - val_error_output_loss: 0.4455 - val_diff_output_loss: 0.0917 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2554
# Epoch 13/100
# 11/11 [==============================] - 2s 141ms/step - loss: 0.5872 - error_output_loss: 0.4537 - diff_output_loss: 0.1335 - error_output_accuracy: 0.4515 - diff_output_mae: 0.3049 - val_loss: 0.5279 - val_error_output_loss: 0.4414 - val_diff_output_loss: 0.0866 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2406
# Epoch 14/100
# 11/11 [==============================] - 1s 114ms/step - loss: 0.5603 - error_output_loss: 0.4450 - diff_output_loss: 0.1153 - error_output_accuracy: 0.5333 - diff_output_mae: 0.2809 - val_loss: 0.5351 - val_error_output_loss: 0.4358 - val_diff_output_loss: 0.0993 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2692
# Epoch 15/100
# 11/11 [==============================] - 2s 144ms/step - loss: 0.5661 - error_output_loss: 0.4466 - diff_output_loss: 0.1195 - error_output_accuracy: 0.5000 - diff_output_mae: 0.2764 - val_loss: 0.5180 - val_error_output_loss: 0.4306 - val_diff_output_loss: 0.0874 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2555
# Epoch 16/100
# 11/11 [==============================] - 1s 138ms/step - loss: 0.5481 - error_output_loss: 0.4383 - diff_output_loss: 0.1098 - error_output_accuracy: 0.5121 - diff_output_mae: 0.2629 - val_loss: 0.5118 - val_error_output_loss: 0.4279 - val_diff_output_loss: 0.0840 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2471
# Epoch 17/100
# 11/11 [==============================] - 1s 108ms/step - loss: 0.5438 - error_output_loss: 0.4349 - diff_output_loss: 0.1089 - error_output_accuracy: 0.5939 - diff_output_mae: 0.2643 - val_loss: 0.5404 - val_error_output_loss: 0.4214 - val_diff_output_loss: 0.1190 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2658
# Epoch 18/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.5505 - error_output_loss: 0.4276 - diff_output_loss: 0.1229 - error_output_accuracy: 0.5242 - diff_output_mae: 0.2815 - val_loss: 0.5147 - val_error_output_loss: 0.4153 - val_diff_output_loss: 0.0995 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2661
# Epoch 19/100
# 11/11 [==============================] - 1s 139ms/step - loss: 0.5453 - error_output_loss: 0.4280 - diff_output_loss: 0.1173 - error_output_accuracy: 0.5515 - diff_output_mae: 0.2755 - val_loss: 0.5110 - val_error_output_loss: 0.4114 - val_diff_output_loss: 0.0995 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2714
# Epoch 20/100
# 11/11 [==============================] - 1s 108ms/step - loss: 0.5424 - error_output_loss: 0.4199 - diff_output_loss: 0.1225 - error_output_accuracy: 0.5515 - diff_output_mae: 0.2823 - val_loss: 0.5467 - val_error_output_loss: 0.4079 - val_diff_output_loss: 0.1387 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2772
# Epoch 21/100
# 11/11 [==============================] - 2s 140ms/step - loss: 0.5404 - error_output_loss: 0.4155 - diff_output_loss: 0.1249 - error_output_accuracy: 0.5788 - diff_output_mae: 0.2833 - val_loss: 0.4928 - val_error_output_loss: 0.4023 - val_diff_output_loss: 0.0905 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2359
# Epoch 22/100
# 11/11 [==============================] - 2s 152ms/step - loss: 0.5305 - error_output_loss: 0.4088 - diff_output_loss: 0.1216 - error_output_accuracy: 0.5939 - diff_output_mae: 0.2821 - val_loss: 0.4711 - val_error_output_loss: 0.3957 - val_diff_output_loss: 0.0754 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2294
# Epoch 23/100
# 11/11 [==============================] - 1s 119ms/step - loss: 0.5120 - error_output_loss: 0.3984 - diff_output_loss: 0.1137 - error_output_accuracy: 0.5788 - diff_output_mae: 0.2678 - val_loss: 0.4966 - val_error_output_loss: 0.3915 - val_diff_output_loss: 0.1051 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2784
# Epoch 24/100
# 11/11 [==============================] - 1s 116ms/step - loss: 0.5215 - error_output_loss: 0.4034 - diff_output_loss: 0.1181 - error_output_accuracy: 0.5545 - diff_output_mae: 0.2779 - val_loss: 0.4736 - val_error_output_loss: 0.3882 - val_diff_output_loss: 0.0854 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2528
# Epoch 25/100
# 11/11 [==============================] - 2s 157ms/step - loss: 0.5117 - error_output_loss: 0.4013 - diff_output_loss: 0.1104 - error_output_accuracy: 0.6000 - diff_output_mae: 0.2681 - val_loss: 0.4560 - val_error_output_loss: 0.3839 - val_diff_output_loss: 0.0722 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2286
# Epoch 26/100
# 11/11 [==============================] - 2s 166ms/step - loss: 0.4967 - error_output_loss: 0.3951 - diff_output_loss: 0.1016 - error_output_accuracy: 0.5909 - diff_output_mae: 0.2589 - val_loss: 0.4503 - val_error_output_loss: 0.3780 - val_diff_output_loss: 0.0723 - val_error_output_accuracy: 0.6145 - val_diff_output_mae: 0.2230
# Epoch 27/100
# 11/11 [==============================] - 1s 119ms/step - loss: 0.4988 - error_output_loss: 0.3895 - diff_output_loss: 0.1094 - error_output_accuracy: 0.5788 - diff_output_mae: 0.2700 - val_loss: 0.4654 - val_error_output_loss: 0.3723 - val_diff_output_loss: 0.0931 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2607
# Epoch 28/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.5317 - error_output_loss: 0.3843 - diff_output_loss: 0.1474 - error_output_accuracy: 0.6030 - diff_output_mae: 0.3156 - val_loss: 0.4858 - val_error_output_loss: 0.3701 - val_diff_output_loss: 0.1157 - val_error_output_accuracy: 0.6386 - val_diff_output_mae: 0.2622
# Epoch 29/100
# 11/11 [==============================] - 2s 163ms/step - loss: 0.4794 - error_output_loss: 0.3779 - diff_output_loss: 0.1016 - error_output_accuracy: 0.6091 - diff_output_mae: 0.2531 - val_loss: 0.4425 - val_error_output_loss: 0.3638 - val_diff_output_loss: 0.0787 - val_error_output_accuracy: 0.6024 - val_diff_output_mae: 0.2372
# Epoch 30/100
# 11/11 [==============================] - 2s 160ms/step - loss: 0.4755 - error_output_loss: 0.3713 - diff_output_loss: 0.1042 - error_output_accuracy: 0.6182 - diff_output_mae: 0.2648 - val_loss: 0.4294 - val_error_output_loss: 0.3555 - val_diff_output_loss: 0.0739 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2364
# Epoch 31/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.4803 - error_output_loss: 0.3650 - diff_output_loss: 0.1153 - error_output_accuracy: 0.6424 - diff_output_mae: 0.2688 - val_loss: 0.4228 - val_error_output_loss: 0.3523 - val_diff_output_loss: 0.0705 - val_error_output_accuracy: 0.6506 - val_diff_output_mae: 0.2307
# Epoch 32/100
# 11/11 [==============================] - 2s 162ms/step - loss: 0.4480 - error_output_loss: 0.3554 - diff_output_loss: 0.0926 - error_output_accuracy: 0.6273 - diff_output_mae: 0.2412 - val_loss: 0.4065 - val_error_output_loss: 0.3426 - val_diff_output_loss: 0.0639 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2132
# Epoch 33/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.4455 - error_output_loss: 0.3478 - diff_output_loss: 0.0977 - error_output_accuracy: 0.6545 - diff_output_mae: 0.2504 - val_loss: 0.4092 - val_error_output_loss: 0.3358 - val_diff_output_loss: 0.0734 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2156
# Epoch 34/100
# 11/11 [==============================] - 2s 155ms/step - loss: 0.4755 - error_output_loss: 0.3403 - diff_output_loss: 0.1352 - error_output_accuracy: 0.6667 - diff_output_mae: 0.2978 - val_loss: 0.3973 - val_error_output_loss: 0.3329 - val_diff_output_loss: 0.0644 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2204
# Epoch 35/100
# 11/11 [==============================] - 1s 115ms/step - loss: 0.4303 - error_output_loss: 0.3349 - diff_output_loss: 0.0953 - error_output_accuracy: 0.6455 - diff_output_mae: 0.2486 - val_loss: 0.4191 - val_error_output_loss: 0.3396 - val_diff_output_loss: 0.0796 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2443
# Epoch 36/100
# 11/11 [==============================] - 2s 160ms/step - loss: 0.4319 - error_output_loss: 0.3309 - diff_output_loss: 0.1009 - error_output_accuracy: 0.6697 - diff_output_mae: 0.2446 - val_loss: 0.3844 - val_error_output_loss: 0.3195 - val_diff_output_loss: 0.0649 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2047
# Epoch 37/100
# 11/11 [==============================] - 1s 121ms/step - loss: 0.4294 - error_output_loss: 0.3267 - diff_output_loss: 0.1027 - error_output_accuracy: 0.6485 - diff_output_mae: 0.2562 - val_loss: 0.3923 - val_error_output_loss: 0.3146 - val_diff_output_loss: 0.0777 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2383
# Epoch 38/100
# 11/11 [==============================] - 2s 151ms/step - loss: 0.4192 - error_output_loss: 0.3209 - diff_output_loss: 0.0983 - error_output_accuracy: 0.7152 - diff_output_mae: 0.2495 - val_loss: 0.3746 - val_error_output_loss: 0.3134 - val_diff_output_loss: 0.0612 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2057
# Epoch 39/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.4227 - error_output_loss: 0.3193 - diff_output_loss: 0.1034 - error_output_accuracy: 0.7030 - diff_output_mae: 0.2559 - val_loss: 0.3772 - val_error_output_loss: 0.3066 - val_diff_output_loss: 0.0706 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2261
# Epoch 40/100
# 11/11 [==============================] - 1s 115ms/step - loss: 0.4116 - error_output_loss: 0.3082 - diff_output_loss: 0.1034 - error_output_accuracy: 0.7030 - diff_output_mae: 0.2608 - val_loss: 0.4375 - val_error_output_loss: 0.3170 - val_diff_output_loss: 0.1205 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2890
# Epoch 41/100
# 11/11 [==============================] - 2s 161ms/step - loss: 0.4153 - error_output_loss: 0.3096 - diff_output_loss: 0.1057 - error_output_accuracy: 0.6970 - diff_output_mae: 0.2539 - val_loss: 0.3685 - val_error_output_loss: 0.3018 - val_diff_output_loss: 0.0667 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2105
# Epoch 42/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.4159 - error_output_loss: 0.3061 - diff_output_loss: 0.1098 - error_output_accuracy: 0.6879 - diff_output_mae: 0.2624 - val_loss: 0.4254 - val_error_output_loss: 0.3007 - val_diff_output_loss: 0.1247 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2866
# Epoch 43/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.4123 - error_output_loss: 0.2992 - diff_output_loss: 0.1131 - error_output_accuracy: 0.7242 - diff_output_mae: 0.2694 - val_loss: 0.3798 - val_error_output_loss: 0.3082 - val_diff_output_loss: 0.0716 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2240
# Epoch 44/100
# 11/11 [==============================] - 1s 115ms/step - loss: 0.4044 - error_output_loss: 0.2896 - diff_output_loss: 0.1148 - error_output_accuracy: 0.7485 - diff_output_mae: 0.2698 - val_loss: 0.3856 - val_error_output_loss: 0.3015 - val_diff_output_loss: 0.0841 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2207
# Epoch 45/100
# 11/11 [==============================] - 1s 129ms/step - loss: 0.4023 - error_output_loss: 0.2884 - diff_output_loss: 0.1139 - error_output_accuracy: 0.7424 - diff_output_mae: 0.2717 - val_loss: 0.3829 - val_error_output_loss: 0.2932 - val_diff_output_loss: 0.0896 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2545
# Epoch 46/100
# 11/11 [==============================] - 1s 120ms/step - loss: 0.4164 - error_output_loss: 0.2840 - diff_output_loss: 0.1324 - error_output_accuracy: 0.7212 - diff_output_mae: 0.2984 - val_loss: 0.3750 - val_error_output_loss: 0.2866 - val_diff_output_loss: 0.0884 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2494
# Epoch 47/100
# 11/11 [==============================] - 1s 114ms/step - loss: 0.3879 - error_output_loss: 0.2755 - diff_output_loss: 0.1124 - error_output_accuracy: 0.7333 - diff_output_mae: 0.2659 - val_loss: 0.3716 - val_error_output_loss: 0.3001 - val_diff_output_loss: 0.0715 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2264
# Epoch 48/100
# 11/11 [==============================] - 1s 119ms/step - loss: 0.3746 - error_output_loss: 0.2802 - diff_output_loss: 0.0945 - error_output_accuracy: 0.7545 - diff_output_mae: 0.2439 - val_loss: 0.4028 - val_error_output_loss: 0.3034 - val_diff_output_loss: 0.0994 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2633
# Epoch 49/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.3745 - error_output_loss: 0.2717 - diff_output_loss: 0.1027 - error_output_accuracy: 0.7333 - diff_output_mae: 0.2541 - val_loss: 0.3762 - val_error_output_loss: 0.2965 - val_diff_output_loss: 0.0797 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2349
# Epoch 50/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.3566 - error_output_loss: 0.2661 - diff_output_loss: 0.0905 - error_output_accuracy: 0.7636 - diff_output_mae: 0.2400 - val_loss: 0.3599 - val_error_output_loss: 0.2902 - val_diff_output_loss: 0.0697 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2213
# Epoch 51/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.3443 - error_output_loss: 0.2556 - diff_output_loss: 0.0887 - error_output_accuracy: 0.7697 - diff_output_mae: 0.2347 - val_loss: 0.3737 - val_error_output_loss: 0.2925 - val_diff_output_loss: 0.0813 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2361
# Epoch 52/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.3575 - error_output_loss: 0.2576 - diff_output_loss: 0.0999 - error_output_accuracy: 0.7697 - diff_output_mae: 0.2483 - val_loss: 0.3736 - val_error_output_loss: 0.3020 - val_diff_output_loss: 0.0717 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2089
# Epoch 53/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.3639 - error_output_loss: 0.2560 - diff_output_loss: 0.1079 - error_output_accuracy: 0.7576 - diff_output_mae: 0.2662 - val_loss: 0.3767 - val_error_output_loss: 0.2946 - val_diff_output_loss: 0.0821 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2252
# Epoch 54/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.3560 - error_output_loss: 0.2508 - diff_output_loss: 0.1052 - error_output_accuracy: 0.7606 - diff_output_mae: 0.2533 - val_loss: 0.3682 - val_error_output_loss: 0.2825 - val_diff_output_loss: 0.0856 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2319
# Epoch 55/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.3586 - error_output_loss: 0.2515 - diff_output_loss: 0.1071 - error_output_accuracy: 0.7879 - diff_output_mae: 0.2595 - val_loss: 0.3558 - val_error_output_loss: 0.2774 - val_diff_output_loss: 0.0784 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2308
# Epoch 56/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.3422 - error_output_loss: 0.2440 - diff_output_loss: 0.0982 - error_output_accuracy: 0.7697 - diff_output_mae: 0.2461 - val_loss: 0.3621 - val_error_output_loss: 0.2867 - val_diff_output_loss: 0.0754 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2334
# Epoch 57/100
# 11/11 [==============================] - 2s 161ms/step - loss: 0.3246 - error_output_loss: 0.2415 - diff_output_loss: 0.0832 - error_output_accuracy: 0.7788 - diff_output_mae: 0.2358 - val_loss: 0.3511 - val_error_output_loss: 0.2826 - val_diff_output_loss: 0.0684 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2112
# Epoch 58/100
# 11/11 [==============================] - 1s 131ms/step - loss: 0.3371 - error_output_loss: 0.2376 - diff_output_loss: 0.0995 - error_output_accuracy: 0.7879 - diff_output_mae: 0.2469 - val_loss: 0.4153 - val_error_output_loss: 0.2759 - val_diff_output_loss: 0.1394 - val_error_output_accuracy: 0.7711 - val_diff_output_mae: 0.3039
# Epoch 59/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.3561 - error_output_loss: 0.2323 - diff_output_loss: 0.1238 - error_output_accuracy: 0.7758 - diff_output_mae: 0.2756 - val_loss: 0.4041 - val_error_output_loss: 0.2841 - val_diff_output_loss: 0.1200 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2890
# Epoch 60/100
# 11/11 [==============================] - 2s 169ms/step - loss: 0.3497 - error_output_loss: 0.2309 - diff_output_loss: 0.1188 - error_output_accuracy: 0.8030 - diff_output_mae: 0.2761 - val_loss: 0.3447 - val_error_output_loss: 0.2742 - val_diff_output_loss: 0.0705 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2169
# Epoch 61/100
# 11/11 [==============================] - 1s 112ms/step - loss: 0.3455 - error_output_loss: 0.2334 - diff_output_loss: 0.1121 - error_output_accuracy: 0.7667 - diff_output_mae: 0.2704 - val_loss: 0.3754 - val_error_output_loss: 0.2790 - val_diff_output_loss: 0.0964 - val_error_output_accuracy: 0.7590 - val_diff_output_mae: 0.2336
# Epoch 62/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.3328 - error_output_loss: 0.2328 - diff_output_loss: 0.1000 - error_output_accuracy: 0.7788 - diff_output_mae: 0.2525 - val_loss: 0.3713 - val_error_output_loss: 0.2838 - val_diff_output_loss: 0.0875 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2370
# Epoch 63/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2985 - error_output_loss: 0.2102 - diff_output_loss: 0.0883 - error_output_accuracy: 0.8121 - diff_output_mae: 0.2368 - val_loss: 0.3546 - val_error_output_loss: 0.2851 - val_diff_output_loss: 0.0696 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2129
# Epoch 64/100
# 11/11 [==============================] - 1s 132ms/step - loss: 0.3118 - error_output_loss: 0.2151 - diff_output_loss: 0.0967 - error_output_accuracy: 0.7970 - diff_output_mae: 0.2442 - val_loss: 0.3613 - val_error_output_loss: 0.2899 - val_diff_output_loss: 0.0715 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2167
# Epoch 65/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2901 - error_output_loss: 0.2112 - diff_output_loss: 0.0790 - error_output_accuracy: 0.8121 - diff_output_mae: 0.2248 - val_loss: 0.3778 - val_error_output_loss: 0.2872 - val_diff_output_loss: 0.0906 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2462
# Epoch 66/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2972 - error_output_loss: 0.2065 - diff_output_loss: 0.0907 - error_output_accuracy: 0.8061 - diff_output_mae: 0.2448 - val_loss: 0.3954 - val_error_output_loss: 0.3133 - val_diff_output_loss: 0.0822 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2296
# Epoch 67/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2998 - error_output_loss: 0.2113 - diff_output_loss: 0.0885 - error_output_accuracy: 0.8000 - diff_output_mae: 0.2345 - val_loss: 0.3995 - val_error_output_loss: 0.3060 - val_diff_output_loss: 0.0934 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2474
# Epoch 68/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.2979 - error_output_loss: 0.2018 - diff_output_loss: 0.0960 - error_output_accuracy: 0.8242 - diff_output_mae: 0.2374 - val_loss: 0.3878 - val_error_output_loss: 0.2862 - val_diff_output_loss: 0.1016 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2568
# Epoch 69/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2872 - error_output_loss: 0.2033 - diff_output_loss: 0.0839 - error_output_accuracy: 0.7970 - diff_output_mae: 0.2279 - val_loss: 0.3664 - val_error_output_loss: 0.2960 - val_diff_output_loss: 0.0704 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2144
# Epoch 70/100
# 11/11 [==============================] - 1s 126ms/step - loss: 0.2811 - error_output_loss: 0.1966 - diff_output_loss: 0.0844 - error_output_accuracy: 0.8091 - diff_output_mae: 0.2316 - val_loss: 0.3865 - val_error_output_loss: 0.2968 - val_diff_output_loss: 0.0897 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2426
# Epoch 71/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2836 - error_output_loss: 0.1919 - diff_output_loss: 0.0917 - error_output_accuracy: 0.8273 - diff_output_mae: 0.2379 - val_loss: 0.3865 - val_error_output_loss: 0.3108 - val_diff_output_loss: 0.0757 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2279
# Epoch 72/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.2824 - error_output_loss: 0.1973 - diff_output_loss: 0.0851 - error_output_accuracy: 0.7970 - diff_output_mae: 0.2317 - val_loss: 0.3613 - val_error_output_loss: 0.2870 - val_diff_output_loss: 0.0743 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2083
# Epoch 73/100
# 11/11 [==============================] - 1s 118ms/step - loss: 0.2990 - error_output_loss: 0.1934 - diff_output_loss: 0.1056 - error_output_accuracy: 0.8091 - diff_output_mae: 0.2554 - val_loss: 0.3781 - val_error_output_loss: 0.3101 - val_diff_output_loss: 0.0680 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2078
# Epoch 74/100
# 11/11 [==============================] - 1s 117ms/step - loss: 0.2950 - error_output_loss: 0.1912 - diff_output_loss: 0.1038 - error_output_accuracy: 0.8152 - diff_output_mae: 0.2513 - val_loss: 0.3484 - val_error_output_loss: 0.2798 - val_diff_output_loss: 0.0686 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2133
# Epoch 75/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.2806 - error_output_loss: 0.1899 - diff_output_loss: 0.0907 - error_output_accuracy: 0.8333 - diff_output_mae: 0.2358 - val_loss: 0.3583 - val_error_output_loss: 0.2719 - val_diff_output_loss: 0.0865 - val_error_output_accuracy: 0.7590 - val_diff_output_mae: 0.2315
# 3/3 [==============================] - 4s 20ms/step
# Validation Difficulty MAE: 0.22
# Model trained and saved!

# %%
from collections import defaultdict
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
result = tutor_loaded.process_word("freind")
print(result)
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# 1/1 [==============================] - 4s 4s/step
# {'word': 'freind', 'correct': False, 'error_types': ['Transpositions'], 'confidences': {'Transpositions': 0.9142406}, 'max_confidence_type': 'Transpositions', 'confidence': 0.9142406, 'predicted_difficulty': 2.77, 'actual_difficulty': 3, 'game_difficulty': 1, 'score': 0, 'level': 1, 'streak': 0}

# %%
from collections import defaultdict

tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)

test_words = ['resgin', 'nowledge', 'appel', 'nife', 'honnest']
results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_difficulty': 0})

for result in results:
    error_type = result['max_confidence_type']
    grouped_results[error_type]['count'] += 1
    grouped_results[error_type]['total_score_change'] += result['score_change']
    grouped_results[error_type]['words'].append(result['word'])
    grouped_results[error_type]['avg_difficulty'] += result['actual_difficulty']

print("\n=== Grouped Results ===")
for error_type, data in grouped_results.items():
    avg_diff = data['avg_difficulty'] / data['count'] if data['count'] > 0 else 0
    rounded_difficulty_level = round(avg_diff)
    print(f"Error Type: {error_type}")
    print(f"  Count: {data['count']}")
    print(f"  Total Score Change: {data['total_score_change']}")
    print(f"  Average Difficulty: {avg_diff:.2f}")
    print(f"  Words: {', '.join(data['words'])}")

    if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
        error_type_words = tutor_loaded.processor.df[
            (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
            (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
        ]

        if not error_type_words.empty:
            suggested_words = error_type_words['Incorrect_Word'].sample(min(5, len(error_type_words))).tolist()
            print(f"  Suggested Words:")
            for i, word in enumerate(suggested_words, 1):
                difficulty = tutor_loaded.processor.get_difficulty(word)
                print(f"    {i}. {word}")
        else:
            print("No suggested words available.")
    else:
        print("dataset not loaded correctly.")
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# 1/1 [==============================] - 4s 4s/step
#
# Word: resgin
# Status: ✗ Incorrect
# Error Types: Transpositions (58.82%)
# Max Confidence Error Type: Transpositions (58.82%)
# Predicted Difficulty: 2.79 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: nowledge
# Status: ✗ Incorrect
# Error Types: Silent Letters (37.61%)
# Max Confidence Error Type: Silent Letters (37.61%)
# Predicted Difficulty: 3.97 | Actual Difficulty: 4
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: appel
# Status: ✗ Incorrect
# Error Types: Transpositions (85.40%)
# Max Confidence Error Type: Transpositions (85.40%)
# Predicted Difficulty: 2.21 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: nife
# Status: ✗ Incorrect
# Error Types: Omission of Letters (37.28%), Silent Letters (62.39%)
# Max Confidence Error Type: Silent Letters (62.39%)
# Predicted Difficulty: 2.18 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: honnest
# Status: ✗ Incorrect
# Error Types: Addition of Letters (97.33%)
# Max Confidence Error Type: Addition of Letters (97.33%)
# Predicted Difficulty: 3.24 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
#
# === Grouped Results ===
# Error Type: Transpositions
#   Count: 2
#   Total Score Change: 0
#   Average Difficulty: 2.50
#   Words: resgin, appel
#   Suggested Words:
#     1. aling
#     2. whilr
#     3. cilmb
#     4. aengel
#     5. palne
# Error Type: Silent Letters
#   Count: 2
#   Total Score Change: 0
#   Average Difficulty: 3.00
#   Words: nowledge, nife
#   Suggested Words:
#     1. forign
#     2. rench
#     3. foren
#     4. autum
#     5. reath
# Error Type: Addition of Letters
#   Count: 1
#   Total Score Change: 0
#   Average Difficulty: 3.00
#   Words: honnest
#   Suggested Words:
#     1. honnest
#     2. ansswer
#     3. plummer
#     4. debries
#     5. reesign

# %%
error_types = list(grouped_results.keys())
error_counts = [grouped_results[et]['count'] for et in error_types]

plt.figure(figsize=(10, 6))
plt.bar(error_types, error_counts, color='skyblue')

plt.xlabel('Error Types')
plt.ylabel('Count')
plt.title('Error Type Distribution')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
