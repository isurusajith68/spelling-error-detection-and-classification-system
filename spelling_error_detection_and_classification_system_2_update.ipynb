# %%
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
from sklearn.metrics import confusion_matrix, classification_report, multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("TensorFlow version: ", tf.__version__)
# Out:
# Num GPUs Available:  1
# Num CPUs Available:  1
# TensorFlow version:  2.18.0

# %%
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 188         ship            sip  Letter-Phoneme Correspondence             4
# 88          door          doorr            Addition of Letters             4
# 141       ladder          lader            Omission of Letters             6
# 127         half            haf                 Silent Letters             4
# 246     daughter      daughtter            Addition of Letters             8
# 595        wreck           reck                 Silent Letters             5
# 515     symphony        simfony  Letter-Phoneme Correspondence             9
# 497        photo           foto  Letter-Phoneme Correspondence             5
# 498      physics         fizics  Letter-Phoneme Correspondence             7
# 329           do            doo            Addition of Letters             2
# 405         sign          signn            Addition of Letters             4
# 603      exhaust         exaust                 Silent Letters             7
# 254         cake          cakke            Addition of Letters             4
# 564          odd             od            Omission of Letters             3
# 541         bell            bel            Omission of Letters             4
# 303       better          beter            Omission of Letters             6
# 382     dinosaur      dinosauur            Addition of Letters             8
# 446     exercise      exerccise            Addition of Letters             8
# 45           for           forr            Addition of Letters             3
# 198       summer          sumer            Omission of Letters             6
#
#      Difficulty_Level
# 188                 2
# 88                  2
# 141                 3
# 127                 2
# 246                 4
# 595                 2
# 515                 4
# 497                 2
# 498                 3
# 329                 1
# 405                 2
# 603                 3
# 254                 2
# 564                 1
# 541                 2
# 303                 3
# 382                 4
# 446                 4
# 45                  1
# 198                 3

# %%
class DataProcessor:
    def __init__(self, dataset_path):
        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)
        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())
        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))
        self._create_char_encoding()
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}
        self.max_difficulty = self.df['Difficulty_Level'].max()
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")

    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word

        edits = jellyfish.levenshtein_distance(word, correct_word)

        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)

        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)

        soundex_match = jellyfish.soundex(word) == jellyfish.soundex(correct_word)
        metaphone_match = jellyfish.metaphone(word) == jellyfish.metaphone(correct_word)
        nysiis_match = jellyfish.nysiis(word) == jellyfish.nysiis(correct_word)


        silent_letter_candidates = ['b', 'g', 'h', 'k', 'l', 'n', 'p', 't', 'w']

        silent_letter_flag = False
        if edits > 0 and soundex_match and not omission_flag and not addition_flag:
            silent_letter_flag = True
        elif edits > 0:
            word_set = set(word)
            correct_set = set(correct_word)
            missing_letters = correct_set - word_set
            silent_letter_flag = any(letter in silent_letter_candidates for letter in missing_letters)

        phoneme_mismatch_flag = not metaphone_match and not transposition_flag and not silent_letter_flag

        common_substitutions = [
            ('f', 'ph'), ('f', 'gh'), ('k', 'ch'), ('k', 'q'),
            ('s', 'c'), ('z', 's'), ('j', 'g'), ('ee', 'ea'),
            ('i', 'y'), ('ks', 'x'), ('shun', 'tion'), ('kw', 'qu')
        ]

        substitution_flag = False
        for sub_pair in common_substitutions:
            if (sub_pair[0] in word and sub_pair[1] in correct_word) or (sub_pair[1] in word and sub_pair[0] in correct_word):
                substitution_flag = True
                break

        doubled_letter_flag = False
        for i in range(len(word)-1):
            if word[i] == word[i+1]:
                if i+1 >= len(correct_word) or i >= len(correct_word) or word[i] != correct_word[i] or word[i+1] != correct_word[i+1]:
                    doubled_letter_flag = True
                    break

        vowels = 'aeiou'
        vowel_confusion = False
        word_vowels = [c for c in word if c in vowels]
        correct_vowels = [c for c in correct_word if c in vowels]
        if len(word_vowels) != len(correct_vowels) or ''.join(word_vowels) != ''.join(correct_vowels):
            vowel_confusion = True

        return np.array([
            edits,
            transposition_flag,
            omission_flag,
            addition_flag,
            phoneme_mismatch_flag,
            silent_letter_flag,
            substitution_flag,
            doubled_letter_flag,
            vowel_confusion,
            int(not soundex_match),
            int(not metaphone_match),
            int(not nysiis_match)
        ], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

# %%
class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("Dataset path must be provided")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("No dataset path provided")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(12,))
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(512, return_sequences=True, dropout=0.2))(x)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.2))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=15, restore_best_weights=True),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()},
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])

        error_preds_binary = (error_preds > 0.5).astype(int)

        print("\n ---Error Type Classification Report---")
        print(classification_report(
            self.y_val_error,
            error_preds_binary,
            target_names=self.processor.error_types,
            zero_division=0
        ))

        print("\n ---Confusion Matrices---")
        mcm = multilabel_confusion_matrix(self.y_val_error, error_preds_binary)

        plt.figure(figsize=(15, 10))
        for i, (matrix, error_type) in enumerate(zip(mcm, self.processor.error_types)):
            plt.subplot(3, 3, i+1)
            sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues',
                      xticklabels=['Predicted Negative', 'Predicted Positive'],
                      yticklabels=['Actual Negative', 'Actual Positive'])
            plt.title(f'Confusion Matrix for {error_type}')
        plt.tight_layout()
        plt.savefig('confusion_matrices.png')
        plt.show()

        print("\n ---Difficulty Prediction---")
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 8))

        plt.subplot(2, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(2, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.subplot(2, 2, 3)
        plt.plot(self.history.history['error_output_loss'], label='Error Classification Loss')
        plt.plot(self.history.history['val_error_output_loss'], label='Val Error Classification Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Error Classification Loss')
        plt.legend()

        plt.subplot(2, 2, 4)
        plt.plot(self.history.history['diff_output_loss'], label='Difficulty Prediction Loss')
        plt.plot(self.history.history['val_diff_output_loss'], label='Val Difficulty Prediction Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Difficulty Prediction Loss')
        plt.legend()

        plt.tight_layout()
        plt.savefig('training_history.png')
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
            confidences = {'Correct': 1.0}
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences,
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - diff_output_loss: 4.2504 - diff_output_mae: 1.7901 - error_output_accuracy: 0.2215 - error_output_loss: 0.7022 - loss: 4.9626 - val_diff_output_loss: 0.9252 - val_diff_output_mae: 0.8599 - val_error_output_accuracy: 0.3551 - val_error_output_loss: 0.6557 - val_loss: 1.6581
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - diff_output_loss: 0.7452 - diff_output_mae: 0.7095 - error_output_accuracy: 0.2873 - error_output_loss: 0.6276 - loss: 1.3739 - val_diff_output_loss: 0.2959 - val_diff_output_mae: 0.4044 - val_error_output_accuracy: 0.2243 - val_error_output_loss: 0.5501 - val_loss: 0.8311
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - diff_output_loss: 0.3507 - diff_output_mae: 0.4746 - error_output_accuracy: 0.2591 - error_output_loss: 0.5392 - loss: 0.8916 - val_diff_output_loss: 0.2793 - val_diff_output_mae: 0.3944 - val_error_output_accuracy: 0.2243 - val_error_output_loss: 0.5116 - val_loss: 0.7769
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - diff_output_loss: 0.3193 - diff_output_mae: 0.4587 - error_output_accuracy: 0.2704 - error_output_loss: 0.5165 - loss: 0.8370 - val_diff_output_loss: 0.2397 - val_diff_output_mae: 0.3704 - val_error_output_accuracy: 0.4112 - val_error_output_loss: 0.5001 - val_loss: 0.7338
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.2836 - diff_output_mae: 0.4331 - error_output_accuracy: 0.3501 - error_output_loss: 0.5033 - loss: 0.7874 - val_diff_output_loss: 0.2279 - val_diff_output_mae: 0.3639 - val_error_output_accuracy: 0.4393 - val_error_output_loss: 0.4911 - val_loss: 0.7099
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.2568 - diff_output_mae: 0.4109 - error_output_accuracy: 0.3679 - error_output_loss: 0.4945 - loss: 0.7509 - val_diff_output_loss: 0.1834 - val_diff_output_mae: 0.3308 - val_error_output_accuracy: 0.5888 - val_error_output_loss: 0.4810 - val_loss: 0.6630
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - diff_output_loss: 0.2278 - diff_output_mae: 0.3914 - error_output_accuracy: 0.4087 - error_output_loss: 0.4873 - loss: 0.7146 - val_diff_output_loss: 0.1659 - val_diff_output_mae: 0.3126 - val_error_output_accuracy: 0.5981 - val_error_output_loss: 0.4715 - val_loss: 0.6329
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.2198 - diff_output_mae: 0.3780 - error_output_accuracy: 0.4954 - error_output_loss: 0.4695 - loss: 0.6893 - val_diff_output_loss: 0.1496 - val_diff_output_mae: 0.3016 - val_error_output_accuracy: 0.4579 - val_error_output_loss: 0.4616 - val_loss: 0.6091
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - diff_output_loss: 0.1887 - diff_output_mae: 0.3404 - error_output_accuracy: 0.5142 - error_output_loss: 0.4627 - loss: 0.6512 - val_diff_output_loss: 0.1426 - val_diff_output_mae: 0.2962 - val_error_output_accuracy: 0.6729 - val_error_output_loss: 0.4482 - val_loss: 0.5881
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - diff_output_loss: 0.2050 - diff_output_mae: 0.3663 - error_output_accuracy: 0.6091 - error_output_loss: 0.4485 - loss: 0.6542 - val_diff_output_loss: 0.1291 - val_diff_output_mae: 0.2789 - val_error_output_accuracy: 0.7757 - val_error_output_loss: 0.4382 - val_loss: 0.5665
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - diff_output_loss: 0.1913 - diff_output_mae: 0.3400 - error_output_accuracy: 0.6788 - error_output_loss: 0.4296 - loss: 0.6216 - val_diff_output_loss: 0.1443 - val_diff_output_mae: 0.2914 - val_error_output_accuracy: 0.7944 - val_error_output_loss: 0.4251 - val_loss: 0.5645
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1436 - diff_output_mae: 0.2948 - error_output_accuracy: 0.6913 - error_output_loss: 0.4225 - loss: 0.5665 - val_diff_output_loss: 0.1398 - val_diff_output_mae: 0.2917 - val_error_output_accuracy: 0.7477 - val_error_output_loss: 0.4111 - val_loss: 0.5496
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.1516 - diff_output_mae: 0.3083 - error_output_accuracy: 0.7488 - error_output_loss: 0.4101 - loss: 0.5617 - val_diff_output_loss: 0.1378 - val_diff_output_mae: 0.2967 - val_error_output_accuracy: 0.8224 - val_error_output_loss: 0.3974 - val_loss: 0.5354
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - diff_output_loss: 0.1520 - diff_output_mae: 0.3151 - error_output_accuracy: 0.7494 - error_output_loss: 0.3943 - loss: 0.5461 - val_diff_output_loss: 0.2205 - val_diff_output_mae: 0.3824 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.3871 - val_loss: 0.6109
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - diff_output_loss: 0.2150 - diff_output_mae: 0.3601 - error_output_accuracy: 0.7575 - error_output_loss: 0.3878 - loss: 0.6026 - val_diff_output_loss: 0.1859 - val_diff_output_mae: 0.3475 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.3756 - val_loss: 0.5583
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.1887 - diff_output_mae: 0.3484 - error_output_accuracy: 0.8136 - error_output_loss: 0.3648 - loss: 0.5537 - val_diff_output_loss: 0.1476 - val_diff_output_mae: 0.2969 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.3616 - val_loss: 0.5060
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - diff_output_loss: 0.1425 - diff_output_mae: 0.3000 - error_output_accuracy: 0.7911 - error_output_loss: 0.3634 - loss: 0.5064 - val_diff_output_loss: 0.1470 - val_diff_output_mae: 0.3020 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.3530 - val_loss: 0.5004
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - diff_output_loss: 0.1680 - diff_output_mae: 0.3174 - error_output_accuracy: 0.8100 - error_output_loss: 0.3488 - loss: 0.5174 - val_diff_output_loss: 0.1843 - val_diff_output_mae: 0.3206 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.3440 - val_loss: 0.5269
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.2098 - diff_output_mae: 0.3493 - error_output_accuracy: 0.8044 - error_output_loss: 0.3436 - loss: 0.5520 - val_diff_output_loss: 0.1534 - val_diff_output_mae: 0.3022 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.3304 - val_loss: 0.4779
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1700 - diff_output_mae: 0.3295 - error_output_accuracy: 0.7941 - error_output_loss: 0.3324 - loss: 0.5028 - val_diff_output_loss: 0.1398 - val_diff_output_mae: 0.2977 - val_error_output_accuracy: 0.8505 - val_error_output_loss: 0.3208 - val_loss: 0.4581
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1553 - diff_output_mae: 0.3051 - error_output_accuracy: 0.8082 - error_output_loss: 0.3255 - loss: 0.4808 - val_diff_output_loss: 0.1540 - val_diff_output_mae: 0.3147 - val_error_output_accuracy: 0.8692 - val_error_output_loss: 0.3122 - val_loss: 0.4647
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.1715 - diff_output_mae: 0.3113 - error_output_accuracy: 0.8622 - error_output_loss: 0.3151 - loss: 0.4865 - val_diff_output_loss: 0.1548 - val_diff_output_mae: 0.3207 - val_error_output_accuracy: 0.8505 - val_error_output_loss: 0.3033 - val_loss: 0.4579
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - diff_output_loss: 0.1618 - diff_output_mae: 0.3114 - error_output_accuracy: 0.8188 - error_output_loss: 0.3051 - loss: 0.4669 - val_diff_output_loss: 0.1513 - val_diff_output_mae: 0.3054 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.2946 - val_loss: 0.4404
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - diff_output_loss: 0.1377 - diff_output_mae: 0.2858 - error_output_accuracy: 0.8241 - error_output_loss: 0.2952 - loss: 0.4329 - val_diff_output_loss: 0.1363 - val_diff_output_mae: 0.2963 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.2854 - val_loss: 0.4279
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - diff_output_loss: 0.1436 - diff_output_mae: 0.3008 - error_output_accuracy: 0.8479 - error_output_loss: 0.2788 - loss: 0.4218 - val_diff_output_loss: 0.1566 - val_diff_output_mae: 0.3175 - val_error_output_accuracy: 0.8692 - val_error_output_loss: 0.2815 - val_loss: 0.4424
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.1490 - diff_output_mae: 0.2844 - error_output_accuracy: 0.8745 - error_output_loss: 0.2710 - loss: 0.4187 - val_diff_output_loss: 0.1442 - val_diff_output_mae: 0.2998 - val_error_output_accuracy: 0.8692 - val_error_output_loss: 0.2690 - val_loss: 0.4134
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - diff_output_loss: 0.1446 - diff_output_mae: 0.2973 - error_output_accuracy: 0.8612 - error_output_loss: 0.2622 - loss: 0.4065 - val_diff_output_loss: 0.1366 - val_diff_output_mae: 0.3018 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.2590 - val_loss: 0.4017
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1489 - diff_output_mae: 0.2919 - error_output_accuracy: 0.8385 - error_output_loss: 0.2640 - loss: 0.4131 - val_diff_output_loss: 0.1831 - val_diff_output_mae: 0.3531 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.2569 - val_loss: 0.4513
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1771 - diff_output_mae: 0.3179 - error_output_accuracy: 0.8586 - error_output_loss: 0.2554 - loss: 0.4333 - val_diff_output_loss: 0.1276 - val_diff_output_mae: 0.2897 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.2473 - val_loss: 0.3784
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1651 - diff_output_mae: 0.3088 - error_output_accuracy: 0.8840 - error_output_loss: 0.2439 - loss: 0.4086 - val_diff_output_loss: 0.1550 - val_diff_output_mae: 0.3094 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.2405 - val_loss: 0.3973
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - diff_output_loss: 0.1484 - diff_output_mae: 0.3029 - error_output_accuracy: 0.8744 - error_output_loss: 0.2322 - loss: 0.3802 - val_diff_output_loss: 0.2247 - val_diff_output_mae: 0.3883 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2364 - val_loss: 0.4744
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1853 - diff_output_mae: 0.3295 - error_output_accuracy: 0.8927 - error_output_loss: 0.2205 - loss: 0.4053 - val_diff_output_loss: 0.1408 - val_diff_output_mae: 0.3151 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.2305 - val_loss: 0.3713
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - diff_output_loss: 0.1879 - diff_output_mae: 0.3288 - error_output_accuracy: 0.8576 - error_output_loss: 0.2276 - loss: 0.4150 - val_diff_output_loss: 0.1701 - val_diff_output_mae: 0.3206 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.2255 - val_loss: 0.3976
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - diff_output_loss: 0.1690 - diff_output_mae: 0.3306 - error_output_accuracy: 0.8755 - error_output_loss: 0.2084 - loss: 0.3779 - val_diff_output_loss: 0.1622 - val_diff_output_mae: 0.3428 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2190 - val_loss: 0.3840
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - diff_output_loss: 0.1383 - diff_output_mae: 0.2980 - error_output_accuracy: 0.8594 - error_output_loss: 0.2162 - loss: 0.3541 - val_diff_output_loss: 0.1874 - val_diff_output_mae: 0.3619 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.2153 - val_loss: 0.4128
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1500 - diff_output_mae: 0.3077 - error_output_accuracy: 0.8957 - error_output_loss: 0.2039 - loss: 0.3544 - val_diff_output_loss: 0.1633 - val_diff_output_mae: 0.3217 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2148 - val_loss: 0.3863
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1422 - diff_output_mae: 0.2787 - error_output_accuracy: 0.9048 - error_output_loss: 0.1991 - loss: 0.3406 - val_diff_output_loss: 0.1566 - val_diff_output_mae: 0.3045 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2106 - val_loss: 0.3697
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - diff_output_loss: 0.1292 - diff_output_mae: 0.2752 - error_output_accuracy: 0.8765 - error_output_loss: 0.2024 - loss: 0.3310 - val_diff_output_loss: 0.1487 - val_diff_output_mae: 0.3091 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2062 - val_loss: 0.3627
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - diff_output_loss: 0.1202 - diff_output_mae: 0.2716 - error_output_accuracy: 0.8877 - error_output_loss: 0.1947 - loss: 0.3148 - val_diff_output_loss: 0.1505 - val_diff_output_mae: 0.3168 - val_error_output_accuracy: 0.8972 - val_error_output_loss: 0.2012 - val_loss: 0.3582
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - diff_output_loss: 0.1396 - diff_output_mae: 0.2898 - error_output_accuracy: 0.9050 - error_output_loss: 0.1863 - loss: 0.3259 - val_diff_output_loss: 0.1567 - val_diff_output_mae: 0.3095 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.1972 - val_loss: 0.3585
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - diff_output_loss: 0.1444 - diff_output_mae: 0.2995 - error_output_accuracy: 0.8987 - error_output_loss: 0.1733 - loss: 0.3184 - val_diff_output_loss: 0.1355 - val_diff_output_mae: 0.3034 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.1891 - val_loss: 0.3271
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - diff_output_loss: 0.1084 - diff_output_mae: 0.2564 - error_output_accuracy: 0.8790 - error_output_loss: 0.1766 - loss: 0.2845 - val_diff_output_loss: 0.1732 - val_diff_output_mae: 0.3440 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.1899 - val_loss: 0.3740
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - diff_output_loss: 0.1222 - diff_output_mae: 0.2751 - error_output_accuracy: 0.8890 - error_output_loss: 0.1787 - loss: 0.3004 - val_diff_output_loss: 0.1636 - val_diff_output_mae: 0.3287 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.1874 - val_loss: 0.3581
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - diff_output_loss: 0.1384 - diff_output_mae: 0.2850 - error_output_accuracy: 0.8973 - error_output_loss: 0.1652 - loss: 0.3042 - val_diff_output_loss: 0.1466 - val_diff_output_mae: 0.3143 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.1855 - val_loss: 0.3346
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1238 - diff_output_mae: 0.2721 - error_output_accuracy: 0.9272 - error_output_loss: 0.1626 - loss: 0.2847 - val_diff_output_loss: 0.1510 - val_diff_output_mae: 0.3245 - val_error_output_accuracy: 0.8879 - val_error_output_loss: 0.1750 - val_loss: 0.3298
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - diff_output_loss: 0.1509 - diff_output_mae: 0.2950 - error_output_accuracy: 0.8950 - error_output_loss: 0.1529 - loss: 0.3034 - val_diff_output_loss: 0.1254 - val_diff_output_mae: 0.2855 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.1746 - val_loss: 0.2991
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - diff_output_loss: 0.1437 - diff_output_mae: 0.2944 - error_output_accuracy: 0.9153 - error_output_loss: 0.1457 - loss: 0.2904 - val_diff_output_loss: 0.1566 - val_diff_output_mae: 0.3281 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.1769 - val_loss: 0.3333
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - diff_output_loss: 0.1543 - diff_output_mae: 0.3061 - error_output_accuracy: 0.9068 - error_output_loss: 0.1457 - loss: 0.2996 - val_diff_output_loss: 0.1589 - val_diff_output_mae: 0.3185 - val_error_output_accuracy: 0.8785 - val_error_output_loss: 0.1717 - val_loss: 0.3411
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - diff_output_loss: 0.1189 - diff_output_mae: 0.2671 - error_output_accuracy: 0.9208 - error_output_loss: 0.1405 - loss: 0.2593 - val_diff_output_loss: 0.1382 - val_diff_output_mae: 0.2970 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.1726 - val_loss: 0.3134
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - diff_output_loss: 0.1289 - diff_output_mae: 0.2858 - error_output_accuracy: 0.9269 - error_output_loss: 0.1274 - loss: 0.2570 - val_diff_output_loss: 0.1573 - val_diff_output_mae: 0.3246 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.1613 - val_loss: 0.3246
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - diff_output_loss: 0.1253 - diff_output_mae: 0.2710 - error_output_accuracy: 0.9295 - error_output_loss: 0.1247 - loss: 0.2502 - val_diff_output_loss: 0.1521 - val_diff_output_mae: 0.3181 - val_error_output_accuracy: 0.8692 - val_error_output_loss: 0.1626 - val_loss: 0.3206
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - diff_output_loss: 0.1288 - diff_output_mae: 0.2817 - error_output_accuracy: 0.9366 - error_output_loss: 0.1248 - loss: 0.2544 - val_diff_output_loss: 0.1318 - val_diff_output_mae: 0.2975 - val_error_output_accuracy: 0.8505 - val_error_output_loss: 0.1645 - val_loss: 0.2981
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1119 - diff_output_mae: 0.2555 - error_output_accuracy: 0.9491 - error_output_loss: 0.1177 - loss: 0.2298 - val_diff_output_loss: 0.1479 - val_diff_output_mae: 0.3161 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.1649 - val_loss: 0.3155
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1336 - diff_output_mae: 0.2876 - error_output_accuracy: 0.9354 - error_output_loss: 0.1136 - loss: 0.2464 - val_diff_output_loss: 0.1375 - val_diff_output_mae: 0.2988 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.1741 - val_loss: 0.3196
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1132 - diff_output_mae: 0.2624 - error_output_accuracy: 0.9524 - error_output_loss: 0.1135 - loss: 0.2272 - val_diff_output_loss: 0.1763 - val_diff_output_mae: 0.3412 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.1586 - val_loss: 0.3449
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1092 - diff_output_mae: 0.2581 - error_output_accuracy: 0.9636 - error_output_loss: 0.1046 - loss: 0.2130 - val_diff_output_loss: 0.1471 - val_diff_output_mae: 0.3126 - val_error_output_accuracy: 0.8505 - val_error_output_loss: 0.1549 - val_loss: 0.3083
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - diff_output_loss: 0.1210 - diff_output_mae: 0.2710 - error_output_accuracy: 0.9247 - error_output_loss: 0.1163 - loss: 0.2377 - val_diff_output_loss: 0.1447 - val_diff_output_mae: 0.3133 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1696 - val_loss: 0.3236
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - diff_output_loss: 0.1038 - diff_output_mae: 0.2536 - error_output_accuracy: 0.9457 - error_output_loss: 0.1118 - loss: 0.2157 - val_diff_output_loss: 0.1467 - val_diff_output_mae: 0.3113 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1662 - val_loss: 0.3203
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - diff_output_loss: 0.1044 - diff_output_mae: 0.2561 - error_output_accuracy: 0.9373 - error_output_loss: 0.1116 - loss: 0.2162 - val_diff_output_loss: 0.1551 - val_diff_output_mae: 0.3152 - val_error_output_accuracy: 0.8598 - val_error_output_loss: 0.1616 - val_loss: 0.3252
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - diff_output_loss: 0.0959 - diff_output_mae: 0.2381 - error_output_accuracy: 0.9521 - error_output_loss: 0.1025 - loss: 0.1984 - val_diff_output_loss: 0.1419 - val_diff_output_mae: 0.2995 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.1624 - val_loss: 0.3087
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - diff_output_loss: 0.1037 - diff_output_mae: 0.2502 - error_output_accuracy: 0.9659 - error_output_loss: 0.0906 - loss: 0.1946 - val_diff_output_loss: 0.1877 - val_diff_output_mae: 0.3354 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1509 - val_loss: 0.3488
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1359 - diff_output_mae: 0.2827 - error_output_accuracy: 0.9753 - error_output_loss: 0.0858 - loss: 0.2230 - val_diff_output_loss: 0.1607 - val_diff_output_mae: 0.3215 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.1520 - val_loss: 0.3117
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.1162 - diff_output_mae: 0.2716 - error_output_accuracy: 0.9685 - error_output_loss: 0.0907 - loss: 0.2078 - val_diff_output_loss: 0.1565 - val_diff_output_mae: 0.3204 - val_error_output_accuracy: 0.8411 - val_error_output_loss: 0.1572 - val_loss: 0.3181
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - diff_output_loss: 0.1048 - diff_output_mae: 0.2525 - error_output_accuracy: 0.9576 - error_output_loss: 0.0905 - loss: 0.1952 - val_diff_output_loss: 0.1494 - val_diff_output_mae: 0.3027 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1623 - val_loss: 0.3146
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - diff_output_loss: 0.0996 - diff_output_mae: 0.2451 - error_output_accuracy: 0.9657 - error_output_loss: 0.0843 - loss: 0.1843 - val_diff_output_loss: 0.1528 - val_diff_output_mae: 0.3114 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1551 - val_loss: 0.3177
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - diff_output_loss: 0.0994 - diff_output_mae: 0.2447 - error_output_accuracy: 0.9455 - error_output_loss: 0.0901 - loss: 0.1898 - val_diff_output_loss: 0.1780 - val_diff_output_mae: 0.3384 - val_error_output_accuracy: 0.8318 - val_error_output_loss: 0.1520 - val_loss: 0.3352
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - diff_output_loss: 0.1003 - diff_output_mae: 0.2432 - error_output_accuracy: 0.9697 - error_output_loss: 0.0768 - loss: 0.1764 - val_diff_output_loss: 0.1819 - val_diff_output_mae: 0.3373 - val_error_output_accuracy: 0.8505 - val_error_output_loss: 0.1484 - val_loss: 0.3337
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step
#
#  ---Error Type Classification Report---
#                                precision    recall  f1-score   support
#
#           Addition of Letters       1.00      1.00      1.00        23
# Letter-Phoneme Correspondence       0.92      0.69      0.79        16
#           Omission of Letters       1.00      0.86      0.93        22
#                Silent Letters       0.87      0.62      0.72        21
#                Transpositions       1.00      0.80      0.89        25
#
#                     micro avg       0.97      0.80      0.88       107
#                     macro avg       0.96      0.79      0.86       107
#                  weighted avg       0.96      0.80      0.87       107
#                   samples avg       0.80      0.80      0.80       107
#
#
#  ---Confusion Matrices---
#  ---Difficulty Prediction---
# Validation Difficulty MAE: 0.30
# Model trained and saved!

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
tutor_loaded.model.summary()
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 8)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 8, 128)         │          3,712 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ not_equal (NotEqual)      │ (None, 8)              │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional             │ (None, 8, 1024)        │      2,625,536 │ embedding[0][0],       │
# │ (Bidirectional)           │                        │                │ not_equal[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_1           │ (None, 8, 512)         │      2,623,488 │ bidirectional[0][0],   │
# │ (Bidirectional)           │                        │                │ not_equal[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d      │ (None, 512)            │              0 │ bidirectional_1[0][0]  │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 12)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 524)            │              0 │ global_max_pooling1d[… │
# │                           │                        │                │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         67,200 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ error_output (Dense)      │ (None, 5)              │            645 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ diff_output (Dense)       │ (None, 1)              │            129 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 15,962,132 (60.89 MB)
#  Trainable params: 5,320,710 (20.30 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 10,641,422 (40.59 MB)

# %%
test_words = [
    'nife',
    'rite',
    'mountan',
    'naw',
    'freind',
    'fone',
    'sykology',
    'aline',
    'safary',
    'kitcehn'
]

results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_confidence': 0.0, 'total_difficulty': 0.0})

for result in results:
    if not result['correct']:
        error_type = result['max_confidence_type']
        grouped_results[error_type]['count'] += 1
        grouped_results[error_type]['total_score_change'] += result['score_change']
        grouped_results[error_type]['words'].append(result['word'])
        grouped_results[error_type]['avg_confidence'] += result['confidence']
        grouped_results[error_type]['total_difficulty'] += result['predicted_difficulty']

print("\n=== Results Analysis by Error Type ===")
for error_type, data in grouped_results.items():
    if data['count'] > 0:
        data['avg_confidence'] /= data['count']
        data['avg_difficulty'] = data['total_difficulty'] / data['count']
        rounded_difficulty_level = round(data['avg_difficulty'])

        print(f"Error Type: {error_type}")
        print(f"  Count: {data['count']}")
        print(f"  Average Confidence: {data['avg_confidence']:.2%}")
        print(f"  Average Difficulty: {data['avg_difficulty']:.2f}")
        print(f"  Words: {', '.join(data['words'])}")

        if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
            error_type_words = tutor_loaded.processor.df[
                (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
                (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
            ]

            if not error_type_words.empty:
                new_words = error_type_words[~error_type_words['Incorrect_Word'].isin(data['words'])]

                if not new_words.empty:
                    suggested_words = new_words['Incorrect_Word'].sample(min(5, len(new_words))).tolist()
                    print(f"  Suggested Words (Difficulty {rounded_difficulty_level}):")
                    for i, word in enumerate(suggested_words, 1):
                        difficulty = tutor_loaded.processor.get_difficulty(word)
                        correct_word = error_type_words[error_type_words['Incorrect_Word'] == word]['Correct_Word'].iloc[0]
                        print(f"    {i}. {word} (correct: {correct_word})")


if grouped_results:
    error_types = list(grouped_results.keys())
    error_counts = [grouped_results[et]['count'] for et in error_types]
    avg_confidences = [grouped_results[et]['avg_confidence'] for et in error_types]

    fig, ax1 = plt.subplots(figsize=(12, 6))

    x = np.arange(len(error_types))
    bars = ax1.bar(x, error_counts, width=0.6, color='skyblue', label='Count')
    ax1.set_xlabel('Error Types')
    ax1.set_ylabel('Count')
    ax1.set_title('Error Type Distribution with Confidence')
    ax1.set_xticks(x)
    ax1.set_xticklabels(error_types, rotation=45, ha='right')

    ax2 = ax1.twinx()
    ax2.plot(x, avg_confidences, 'ro-', label='Confidence')
    ax2.set_ylabel('Average Confidence')
    ax2.set_ylim([0, 1])

    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper left')

    plt.tight_layout()
    plt.savefig('error_analysis.png')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
#
# Word: nife
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (44.45%), Silent Letters (66.83%)
# Max Confidence Error Type: Silent Letters (66.83%)
# Predicted Difficulty: 2.23 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Word: rite
# Status: ✗ Incorrect
# Error Types: Silent Letters (68.88%)
# Max Confidence Error Type: Silent Letters (68.88%)
# Predicted Difficulty: 2.19 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Word: mountan
# Status: ✗ Incorrect
# Error Types: Omission of Letters (51.46%)
# Max Confidence Error Type: Omission of Letters (51.46%)
# Predicted Difficulty: 3.71 | Actual Difficulty: 4
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Word: naw
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (46.75%), Silent Letters (67.16%)
# Max Confidence Error Type: Silent Letters (67.16%)
# Predicted Difficulty: 2.06 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Word: freind
# Status: ✗ Incorrect
# Error Types: Transpositions (80.58%)
# Max Confidence Error Type: Transpositions (80.58%)
# Predicted Difficulty: 2.51 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Word: fone
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (83.48%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (83.48%)
# Predicted Difficulty: 2.36 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Word: sykology
# Status: ✗ Incorrect
# Error Types: Omission of Letters (36.64%), Silent Letters (51.62%)
# Max Confidence Error Type: Silent Letters (51.62%)
# Predicted Difficulty: 2.73 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Word: aline
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (40.84%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (40.84%)
# Predicted Difficulty: 2.32 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Word: safary
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (87.40%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (87.40%)
# Predicted Difficulty: 2.76 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Word: kitcehn
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (50.16%), Transpositions (76.66%)
# Max Confidence Error Type: Transpositions (76.66%)
# Predicted Difficulty: 2.99 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
#
# === Results Analysis by Error Type ===
# Error Type: Silent Letters
#   Count: 4
#   Average Confidence: 63.62%
#   Average Difficulty: 2.30
#   Words: nife, rite, naw, sykology
#   Suggested Words (Difficulty 2):
#     1. no (correct: know)
#     2. ren (correct: wren)
#     3. salm (correct: psalm)
#     4. wom (correct: womb)
#     5. haf (correct: half)
# Error Type: Omission of Letters
#   Count: 1
#   Average Confidence: 51.46%
#   Average Difficulty: 3.71
#   Words: mountan
#   Suggested Words (Difficulty 4):
#     1. begining (correct: beginning)
#     2. bathrom (correct: bathroom)
#     3. tomorow (correct: tomorrow)
#     4. wining (correct: winning)
#     5. schol (correct: school)
# Error Type: Transpositions
#   Count: 2
#   Average Confidence: 78.62%
#   Average Difficulty: 2.75
#   Words: freind, kitcehn
#   Suggested Words (Difficulty 3):
#     1. teahcer (correct: teacher)
#     2. floewr (correct: flower)
#     3. stuednt (correct: student)
#     4. baskte (correct: basket)
#     5. chikecn (correct: chicken)
# Error Type: Letter-Phoneme Correspondence
#   Count: 3
#   Average Confidence: 70.57%
#   Average Difficulty: 2.48
#   Words: fone, aline, safary
#   Suggested Words (Difficulty 2):
#     1. shur (correct: sure)
#     2. nise (correct: nice)
#     3. rise (correct: rice)
#     4. graf (correct: graph)
#     5. rase (correct: race)
