# %%
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
from sklearn.metrics import confusion_matrix, classification_report, multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("TensorFlow version: ", tf.__version__)
# Out:
# Num GPUs Available:  0
# Num CPUs Available:  1
# TensorFlow version:  2.15.0

# %%
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 377        crumb           crum                 Silent Letters             5
# 370          fox            fxo                 Transpositions             3
# 69     different     differente            Addition of Letters             9
# 369       window        windoww            Addition of Letters             6
# 52           the            teh                 Transpositions             3
# 615         lamb            lam                 Silent Letters             4
# 510      dolphin         dolfin  Letter-Phoneme Correspondence             7
# 486         cold           clod                 Transpositions             4
# 337          big            bgi                 Transpositions             3
# 265   philosophy       filosofy  Letter-Phoneme Correspondence            10
# 482         note           ntoe                 Transpositions             4
# 125           on            onn            Addition of Letters             2
# 316     hospital      hospitall            Addition of Letters             8
# 470        apple          appel                 Transpositions             5
# 541         bell            bel            Omission of Letters             4
# 519         sure           shur  Letter-Phoneme Correspondence             4
# 513   philosophy       filosofy  Letter-Phoneme Correspondence            10
# 606   psychology      psycology                 Silent Letters            10
# 517    xylophone       zylofone  Letter-Phoneme Correspondence             9
# 306        fence           fens  Letter-Phoneme Correspondence             5
#
#      Difficulty_Level
# 377                 2
# 370                 1
# 69                  4
# 369                 3
# 52                  1
# 615                 2
# 510                 3
# 486                 1
# 337                 1
# 265                 4
# 482                 1
# 125                 1
# 316                 4
# 470                 2
# 541                 2
# 519                 2
# 513                 4
# 606                 3
# 517                 4
# 306                 2

# %%
class DataProcessor:
    def __init__(self, dataset_path):
        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)
        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())
        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))
        self._create_char_encoding()
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}
        self.max_difficulty = self.df['Difficulty_Level'].max()
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")

    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word
        
        edits = jellyfish.levenshtein_distance(word, correct_word)
        
        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)
        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)
        soundex_match = jellyfish.soundex(word) == jellyfish.soundex(correct_word)
        metaphone_match = jellyfish.metaphone(word) == jellyfish.metaphone(correct_word)
        nysiis_match = jellyfish.nysiis(word) == jellyfish.nysiis(correct_word)
        
        silent_letter_flag = False
        
        silent_letter_patterns = {
            'k': ['kn'], 'w': ['wr'], 'b': ['mb'], 'h': ['gh', 'rh', 'wh'],
            'l': ['lk', 'lm'], 'g': ['gn'], 'p': ['ps', 'pn'], 't': ['tch', 'tle'],
            'n': ['mn'], 'u': ['gu'], 'c': ['sc']
        }
        
        if omission_flag:
            for silent_letter, patterns in silent_letter_patterns.items():
                for pattern in patterns:
                    if any(pattern in correct_word and pattern not in word for pattern in patterns):
                        silent_letter_flag = True
                        break
        
        common_silent_combinations = [
            ('k', 'kn', 'n'),  
            ('g', 'gn', 'n'),  
            ('w', 'wr', 'r'),  
            ('p', 'ps', 's'),  
            ('b', 'mb', 'm'),  
            ('h', 'gh', 'g')   
        ]
        
        for silent_letter, full_pattern, shortened in common_silent_combinations:
            if shortened in word and full_pattern in correct_word:
                silent_letter_flag = True
                break
        
        if correct_word.endswith('e') and not word.endswith('e') and soundex_match:
            silent_letter_flag = True
        
        phoneme_mismatch_flag = not metaphone_match and not transposition_flag and not silent_letter_flag
        
        common_substitutions = [
            ('f', 'ph'), ('f', 'gh'), ('k', 'ch'), ('k', 'q'),
            ('s', 'c'), ('z', 's'), ('j', 'g'), ('ee', 'ea'),
            ('i', 'y'), ('ks', 'x'), ('shun', 'tion'), ('kw', 'qu')
        ]
        
        substitution_flag = False
        for sub_pair in common_substitutions:
            if (sub_pair[0] in word and sub_pair[1] in correct_word) or (sub_pair[1] in word and sub_pair[0] in correct_word):
                substitution_flag = True
                break
        
        doubled_letter_flag = False
        for i in range(len(word)-1):
            if word[i] == word[i+1]:
                if i+1 >= len(correct_word) or i >= len(correct_word) or word[i] != correct_word[i] or word[i+1] != correct_word[i+1]:
                    doubled_letter_flag = True
                    break
        
        vowels = 'aeiou'
        vowel_confusion = False
        word_vowels = [c for c in word if c in vowels]
        correct_vowels = [c for c in correct_word if c in vowels]
        if len(word_vowels) != len(correct_vowels) or ''.join(word_vowels) != ''.join(correct_vowels):
            vowel_confusion = True
        
        return np.array([
            edits,
            transposition_flag,
            omission_flag,
            addition_flag,
            phoneme_mismatch_flag,
            silent_letter_flag,
            substitution_flag,
            doubled_letter_flag,
            vowel_confusion,
            int(not soundex_match),
            int(not metaphone_match),
            int(not nysiis_match)
        ], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

# %%
class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("Dataset path must be provided")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("No dataset path provided")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(12,))
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(512, return_sequences=True, dropout=0.2))(x)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.2))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=15, restore_best_weights=True),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()},
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])

        error_preds_binary = (error_preds > 0.5).astype(int)

        print("\n ---Error Type Classification Report---")
        print(classification_report(
            self.y_val_error,
            error_preds_binary,
            target_names=self.processor.error_types,
            zero_division=0
        ))

        print("\n ---Confusion Matrices---")
        mcm = multilabel_confusion_matrix(self.y_val_error, error_preds_binary)

        plt.figure(figsize=(15, 10))
        for i, (matrix, error_type) in enumerate(zip(mcm, self.processor.error_types)):
            plt.subplot(3, 3, i+1)
            sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues',
                      xticklabels=['Predicted Negative', 'Predicted Positive'],
                      yticklabels=['Actual Negative', 'Actual Positive'])
            plt.title(f'Confusion Matrix for {error_type}')
        plt.tight_layout()
        plt.savefig('confusion_matrices.png')
        plt.show()

        print("\n ---Difficulty Prediction---")
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 8))

        plt.subplot(2, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(2, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.subplot(2, 2, 3)
        plt.plot(self.history.history['error_output_loss'], label='Error Classification Loss')
        plt.plot(self.history.history['val_error_output_loss'], label='Val Error Classification Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Error Classification Loss')
        plt.legend()

        plt.subplot(2, 2, 4)
        plt.plot(self.history.history['diff_output_loss'], label='Difficulty Prediction Loss')
        plt.plot(self.history.history['val_diff_output_loss'], label='Val Difficulty Prediction Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Difficulty Prediction Loss')
        plt.legend()

        plt.tight_layout()
        plt.savefig('training_history.png')
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
            confidences = {'Correct': 1.0}
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences,
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/100
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 14/14 [==============================] - 20s 509ms/step - loss: 3.6218 - error_output_loss: 0.6708 - diff_output_loss: 2.9510 - error_output_accuracy: 0.1486 - diff_output_mae: 1.3913 - val_loss: 1.9865 - val_error_output_loss: 0.6375 - val_diff_output_loss: 1.3490 - val_error_output_accuracy: 0.2336 - val_diff_output_mae: 1.0080
# Epoch 2/100
# 14/14 [==============================] - 2s 140ms/step - loss: 1.4428 - error_output_loss: 0.6069 - diff_output_loss: 0.8359 - error_output_accuracy: 0.1816 - diff_output_mae: 0.7377 - val_loss: 0.9316 - val_error_output_loss: 0.5542 - val_diff_output_loss: 0.3775 - val_error_output_accuracy: 0.2336 - val_diff_output_mae: 0.5124
# Epoch 3/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.9175 - error_output_loss: 0.5480 - diff_output_loss: 0.3695 - error_output_accuracy: 0.2123 - diff_output_mae: 0.4815 - val_loss: 0.7633 - val_error_output_loss: 0.5173 - val_diff_output_loss: 0.2460 - val_error_output_accuracy: 0.2336 - val_diff_output_mae: 0.3882
# Epoch 4/100
# 14/14 [==============================] - 2s 142ms/step - loss: 0.8077 - error_output_loss: 0.5118 - diff_output_loss: 0.2959 - error_output_accuracy: 0.2524 - diff_output_mae: 0.4294 - val_loss: 0.7100 - val_error_output_loss: 0.4984 - val_diff_output_loss: 0.2116 - val_error_output_accuracy: 0.3551 - val_diff_output_mae: 0.3622
# Epoch 5/100
# 14/14 [==============================] - 2s 140ms/step - loss: 0.7887 - error_output_loss: 0.5002 - diff_output_loss: 0.2886 - error_output_accuracy: 0.3231 - diff_output_mae: 0.4282 - val_loss: 0.6785 - val_error_output_loss: 0.4905 - val_diff_output_loss: 0.1880 - val_error_output_accuracy: 0.4299 - val_diff_output_mae: 0.3456
# Epoch 6/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.7255 - error_output_loss: 0.4945 - diff_output_loss: 0.2309 - error_output_accuracy: 0.3915 - diff_output_mae: 0.3851 - val_loss: 0.6498 - val_error_output_loss: 0.4828 - val_diff_output_loss: 0.1670 - val_error_output_accuracy: 0.5794 - val_diff_output_mae: 0.3253
# Epoch 7/100
# 14/14 [==============================] - 2s 135ms/step - loss: 0.6874 - error_output_loss: 0.4804 - diff_output_loss: 0.2070 - error_output_accuracy: 0.5024 - diff_output_mae: 0.3651 - val_loss: 0.6325 - val_error_output_loss: 0.4721 - val_diff_output_loss: 0.1604 - val_error_output_accuracy: 0.6822 - val_diff_output_mae: 0.3157
# Epoch 8/100
# 14/14 [==============================] - 2s 136ms/step - loss: 0.6675 - error_output_loss: 0.4697 - diff_output_loss: 0.1978 - error_output_accuracy: 0.5542 - diff_output_mae: 0.3509 - val_loss: 0.6137 - val_error_output_loss: 0.4597 - val_diff_output_loss: 0.1541 - val_error_output_accuracy: 0.6168 - val_diff_output_mae: 0.3064
# Epoch 9/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.6873 - error_output_loss: 0.4561 - diff_output_loss: 0.2313 - error_output_accuracy: 0.6108 - diff_output_mae: 0.3800 - val_loss: 0.5912 - val_error_output_loss: 0.4491 - val_diff_output_loss: 0.1421 - val_error_output_accuracy: 0.6542 - val_diff_output_mae: 0.2976
# Epoch 10/100
# 14/14 [==============================] - 2s 136ms/step - loss: 0.6493 - error_output_loss: 0.4430 - diff_output_loss: 0.2063 - error_output_accuracy: 0.6108 - diff_output_mae: 0.3570 - val_loss: 0.5770 - val_error_output_loss: 0.4377 - val_diff_output_loss: 0.1393 - val_error_output_accuracy: 0.7757 - val_diff_output_mae: 0.2936
# Epoch 11/100
# 14/14 [==============================] - 2s 137ms/step - loss: 0.6139 - error_output_loss: 0.4346 - diff_output_loss: 0.1793 - error_output_accuracy: 0.6698 - diff_output_mae: 0.3322 - val_loss: 0.5538 - val_error_output_loss: 0.4242 - val_diff_output_loss: 0.1296 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2875
# Epoch 12/100
# 14/14 [==============================] - 2s 156ms/step - loss: 0.6039 - error_output_loss: 0.4247 - diff_output_loss: 0.1793 - error_output_accuracy: 0.6745 - diff_output_mae: 0.3388 - val_loss: 0.5486 - val_error_output_loss: 0.4117 - val_diff_output_loss: 0.1370 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.2923
# Epoch 13/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.5781 - error_output_loss: 0.4092 - diff_output_loss: 0.1689 - error_output_accuracy: 0.6910 - diff_output_mae: 0.3242 - val_loss: 0.5204 - val_error_output_loss: 0.3995 - val_diff_output_loss: 0.1208 - val_error_output_accuracy: 0.8037 - val_diff_output_mae: 0.2796
# Epoch 14/100
# 14/14 [==============================] - 2s 110ms/step - loss: 0.5658 - error_output_loss: 0.3975 - diff_output_loss: 0.1682 - error_output_accuracy: 0.7193 - diff_output_mae: 0.3178 - val_loss: 0.5606 - val_error_output_loss: 0.3878 - val_diff_output_loss: 0.1728 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3342
# Epoch 15/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.5551 - error_output_loss: 0.3851 - diff_output_loss: 0.1699 - error_output_accuracy: 0.7712 - diff_output_mae: 0.3254 - val_loss: 0.5029 - val_error_output_loss: 0.3740 - val_diff_output_loss: 0.1289 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.2862
# Epoch 16/100
# 14/14 [==============================] - 2s 143ms/step - loss: 0.5390 - error_output_loss: 0.3739 - diff_output_loss: 0.1651 - error_output_accuracy: 0.7807 - diff_output_mae: 0.3181 - val_loss: 0.4960 - val_error_output_loss: 0.3600 - val_diff_output_loss: 0.1360 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2975
# Epoch 17/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.5339 - error_output_loss: 0.3608 - diff_output_loss: 0.1731 - error_output_accuracy: 0.8137 - diff_output_mae: 0.3206 - val_loss: 0.4816 - val_error_output_loss: 0.3497 - val_diff_output_loss: 0.1318 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2918
# Epoch 18/100
# 14/14 [==============================] - 2s 135ms/step - loss: 0.5113 - error_output_loss: 0.3446 - diff_output_loss: 0.1667 - error_output_accuracy: 0.8160 - diff_output_mae: 0.3120 - val_loss: 0.4892 - val_error_output_loss: 0.3379 - val_diff_output_loss: 0.1513 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3092
# Epoch 19/100
# 14/14 [==============================] - 2s 147ms/step - loss: 0.4995 - error_output_loss: 0.3305 - diff_output_loss: 0.1690 - error_output_accuracy: 0.8302 - diff_output_mae: 0.3210 - val_loss: 0.4724 - val_error_output_loss: 0.3255 - val_diff_output_loss: 0.1469 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3080
# Epoch 20/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.4951 - error_output_loss: 0.3248 - diff_output_loss: 0.1703 - error_output_accuracy: 0.8278 - diff_output_mae: 0.3175 - val_loss: 0.4772 - val_error_output_loss: 0.3160 - val_diff_output_loss: 0.1612 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.3180
# Epoch 21/100
# 14/14 [==============================] - 2s 126ms/step - loss: 0.4909 - error_output_loss: 0.3144 - diff_output_loss: 0.1764 - error_output_accuracy: 0.8443 - diff_output_mae: 0.3275 - val_loss: 0.5259 - val_error_output_loss: 0.3080 - val_diff_output_loss: 0.2179 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3612
# Epoch 22/100
# 14/14 [==============================] - 2s 143ms/step - loss: 0.4952 - error_output_loss: 0.3073 - diff_output_loss: 0.1879 - error_output_accuracy: 0.8467 - diff_output_mae: 0.3329 - val_loss: 0.4342 - val_error_output_loss: 0.2968 - val_diff_output_loss: 0.1374 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3038
# Epoch 23/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.4498 - error_output_loss: 0.2968 - diff_output_loss: 0.1530 - error_output_accuracy: 0.8561 - diff_output_mae: 0.3013 - val_loss: 0.4338 - val_error_output_loss: 0.2865 - val_diff_output_loss: 0.1473 - val_error_output_accuracy: 0.8972 - val_diff_output_mae: 0.3129
# Epoch 24/100
# 14/14 [==============================] - 2s 156ms/step - loss: 0.4277 - error_output_loss: 0.2834 - diff_output_loss: 0.1443 - error_output_accuracy: 0.8608 - diff_output_mae: 0.2988 - val_loss: 0.4311 - val_error_output_loss: 0.2793 - val_diff_output_loss: 0.1518 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3150
# Epoch 25/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.4299 - error_output_loss: 0.2804 - diff_output_loss: 0.1495 - error_output_accuracy: 0.8561 - diff_output_mae: 0.2944 - val_loss: 0.4207 - val_error_output_loss: 0.2695 - val_diff_output_loss: 0.1512 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3138
# Epoch 26/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.4085 - error_output_loss: 0.2660 - diff_output_loss: 0.1425 - error_output_accuracy: 0.8608 - diff_output_mae: 0.2926 - val_loss: 0.4158 - val_error_output_loss: 0.2624 - val_diff_output_loss: 0.1534 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3110
# Epoch 27/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.4011 - error_output_loss: 0.2670 - diff_output_loss: 0.1340 - error_output_accuracy: 0.8726 - diff_output_mae: 0.2882 - val_loss: 0.3939 - val_error_output_loss: 0.2563 - val_diff_output_loss: 0.1376 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3030
# Epoch 28/100
# 14/14 [==============================] - 2s 147ms/step - loss: 0.3896 - error_output_loss: 0.2548 - diff_output_loss: 0.1349 - error_output_accuracy: 0.8679 - diff_output_mae: 0.2791 - val_loss: 0.3789 - val_error_output_loss: 0.2469 - val_diff_output_loss: 0.1320 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.2888
# Epoch 29/100
# 14/14 [==============================] - 2s 135ms/step - loss: 0.3769 - error_output_loss: 0.2396 - diff_output_loss: 0.1374 - error_output_accuracy: 0.8774 - diff_output_mae: 0.2789 - val_loss: 0.3908 - val_error_output_loss: 0.2411 - val_diff_output_loss: 0.1498 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3045
# Epoch 30/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.3816 - error_output_loss: 0.2384 - diff_output_loss: 0.1432 - error_output_accuracy: 0.8915 - diff_output_mae: 0.2933 - val_loss: 0.3950 - val_error_output_loss: 0.2344 - val_diff_output_loss: 0.1606 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3269
# Epoch 31/100
# 14/14 [==============================] - 2s 172ms/step - loss: 0.3656 - error_output_loss: 0.2293 - diff_output_loss: 0.1363 - error_output_accuracy: 0.8868 - diff_output_mae: 0.2844 - val_loss: 0.3784 - val_error_output_loss: 0.2280 - val_diff_output_loss: 0.1503 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3130
# Epoch 32/100
# 14/14 [==============================] - 3s 206ms/step - loss: 0.3803 - error_output_loss: 0.2268 - diff_output_loss: 0.1535 - error_output_accuracy: 0.8821 - diff_output_mae: 0.2960 - val_loss: 0.3680 - val_error_output_loss: 0.2225 - val_diff_output_loss: 0.1455 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3039
# Epoch 33/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.3528 - error_output_loss: 0.2193 - diff_output_loss: 0.1336 - error_output_accuracy: 0.8656 - diff_output_mae: 0.2882 - val_loss: 0.3871 - val_error_output_loss: 0.2164 - val_diff_output_loss: 0.1708 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3195
# Epoch 34/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.3648 - error_output_loss: 0.2105 - diff_output_loss: 0.1543 - error_output_accuracy: 0.8750 - diff_output_mae: 0.2993 - val_loss: 0.3715 - val_error_output_loss: 0.2118 - val_diff_output_loss: 0.1597 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3255
# Epoch 35/100
# 14/14 [==============================] - 2s 133ms/step - loss: 0.3498 - error_output_loss: 0.2032 - diff_output_loss: 0.1466 - error_output_accuracy: 0.8844 - diff_output_mae: 0.3000 - val_loss: 0.3687 - val_error_output_loss: 0.2072 - val_diff_output_loss: 0.1614 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3234
# Epoch 36/100
# 14/14 [==============================] - 2s 125ms/step - loss: 0.3526 - error_output_loss: 0.2017 - diff_output_loss: 0.1509 - error_output_accuracy: 0.8986 - diff_output_mae: 0.3103 - val_loss: 0.3976 - val_error_output_loss: 0.2041 - val_diff_output_loss: 0.1935 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3398
# Epoch 37/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.3249 - error_output_loss: 0.1949 - diff_output_loss: 0.1300 - error_output_accuracy: 0.8868 - diff_output_mae: 0.2820 - val_loss: 0.3474 - val_error_output_loss: 0.2001 - val_diff_output_loss: 0.1473 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3022
# Epoch 38/100
# 14/14 [==============================] - 2s 156ms/step - loss: 0.3165 - error_output_loss: 0.1928 - diff_output_loss: 0.1237 - error_output_accuracy: 0.8821 - diff_output_mae: 0.2661 - val_loss: 0.3324 - val_error_output_loss: 0.1970 - val_diff_output_loss: 0.1354 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2968
# Epoch 39/100
# 14/14 [==============================] - 2s 120ms/step - loss: 0.3122 - error_output_loss: 0.1901 - diff_output_loss: 0.1220 - error_output_accuracy: 0.8821 - diff_output_mae: 0.2754 - val_loss: 0.3477 - val_error_output_loss: 0.1917 - val_diff_output_loss: 0.1560 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3138
# Epoch 40/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.3130 - error_output_loss: 0.1824 - diff_output_loss: 0.1306 - error_output_accuracy: 0.8915 - diff_output_mae: 0.2808 - val_loss: 0.3465 - val_error_output_loss: 0.1915 - val_diff_output_loss: 0.1550 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3177
# Epoch 41/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.2972 - error_output_loss: 0.1728 - diff_output_loss: 0.1244 - error_output_accuracy: 0.9033 - diff_output_mae: 0.2727 - val_loss: 0.3282 - val_error_output_loss: 0.1883 - val_diff_output_loss: 0.1399 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2989
# Epoch 42/100
# 14/14 [==============================] - 2s 121ms/step - loss: 0.3011 - error_output_loss: 0.1671 - diff_output_loss: 0.1340 - error_output_accuracy: 0.8939 - diff_output_mae: 0.2869 - val_loss: 0.3283 - val_error_output_loss: 0.1844 - val_diff_output_loss: 0.1439 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3042
# Epoch 43/100
# 14/14 [==============================] - 2s 121ms/step - loss: 0.2856 - error_output_loss: 0.1651 - diff_output_loss: 0.1205 - error_output_accuracy: 0.9057 - diff_output_mae: 0.2638 - val_loss: 0.3411 - val_error_output_loss: 0.1827 - val_diff_output_loss: 0.1584 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3160
# Epoch 44/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.2870 - error_output_loss: 0.1627 - diff_output_loss: 0.1243 - error_output_accuracy: 0.8915 - diff_output_mae: 0.2736 - val_loss: 0.3147 - val_error_output_loss: 0.1817 - val_diff_output_loss: 0.1331 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2904
# Epoch 45/100
# 14/14 [==============================] - 2s 117ms/step - loss: 0.2991 - error_output_loss: 0.1603 - diff_output_loss: 0.1388 - error_output_accuracy: 0.8844 - diff_output_mae: 0.2870 - val_loss: 0.3290 - val_error_output_loss: 0.1793 - val_diff_output_loss: 0.1497 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3079
# Epoch 46/100
# 14/14 [==============================] - 5s 392ms/step - loss: 0.2945 - error_output_loss: 0.1558 - diff_output_loss: 0.1387 - error_output_accuracy: 0.8915 - diff_output_mae: 0.2839 - val_loss: 0.3124 - val_error_output_loss: 0.1736 - val_diff_output_loss: 0.1388 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2976
# Epoch 47/100
# 14/14 [==============================] - 5s 346ms/step - loss: 0.3083 - error_output_loss: 0.1566 - diff_output_loss: 0.1516 - error_output_accuracy: 0.9080 - diff_output_mae: 0.3029 - val_loss: 0.3098 - val_error_output_loss: 0.1732 - val_diff_output_loss: 0.1366 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2940
# Epoch 48/100
# 14/14 [==============================] - 8s 581ms/step - loss: 0.2790 - error_output_loss: 0.1451 - diff_output_loss: 0.1339 - error_output_accuracy: 0.9175 - diff_output_mae: 0.2804 - val_loss: 0.2961 - val_error_output_loss: 0.1679 - val_diff_output_loss: 0.1282 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2881
# Epoch 49/100
# 14/14 [==============================] - 2s 112ms/step - loss: 0.2705 - error_output_loss: 0.1410 - diff_output_loss: 0.1295 - error_output_accuracy: 0.9033 - diff_output_mae: 0.2807 - val_loss: 0.3071 - val_error_output_loss: 0.1697 - val_diff_output_loss: 0.1374 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3025
# Epoch 50/100
# 14/14 [==============================] - 7s 495ms/step - loss: 0.2884 - error_output_loss: 0.1440 - diff_output_loss: 0.1444 - error_output_accuracy: 0.9080 - diff_output_mae: 0.2937 - val_loss: 0.2921 - val_error_output_loss: 0.1643 - val_diff_output_loss: 0.1279 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.2875
# Epoch 51/100
# 14/14 [==============================] - 2s 142ms/step - loss: 0.2653 - error_output_loss: 0.1368 - diff_output_loss: 0.1284 - error_output_accuracy: 0.9057 - diff_output_mae: 0.2773 - val_loss: 0.2864 - val_error_output_loss: 0.1636 - val_diff_output_loss: 0.1228 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.2796
# Epoch 52/100
# 14/14 [==============================] - 2s 108ms/step - loss: 0.2561 - error_output_loss: 0.1364 - diff_output_loss: 0.1197 - error_output_accuracy: 0.9127 - diff_output_mae: 0.2692 - val_loss: 0.3104 - val_error_output_loss: 0.1653 - val_diff_output_loss: 0.1452 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.3030
# Epoch 53/100
# 14/14 [==============================] - 2s 116ms/step - loss: 0.2569 - error_output_loss: 0.1256 - diff_output_loss: 0.1313 - error_output_accuracy: 0.9269 - diff_output_mae: 0.2811 - val_loss: 0.3011 - val_error_output_loss: 0.1715 - val_diff_output_loss: 0.1296 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.2847
# Epoch 54/100
# 14/14 [==============================] - 2s 110ms/step - loss: 0.2561 - error_output_loss: 0.1293 - diff_output_loss: 0.1268 - error_output_accuracy: 0.9269 - diff_output_mae: 0.2757 - val_loss: 0.3243 - val_error_output_loss: 0.1697 - val_diff_output_loss: 0.1546 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3192
# Epoch 55/100
# 14/14 [==============================] - 2s 113ms/step - loss: 0.2495 - error_output_loss: 0.1229 - diff_output_loss: 0.1266 - error_output_accuracy: 0.9340 - diff_output_mae: 0.2762 - val_loss: 0.3171 - val_error_output_loss: 0.1668 - val_diff_output_loss: 0.1503 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3213
# Epoch 56/100
# 14/14 [==============================] - 2s 118ms/step - loss: 0.2352 - error_output_loss: 0.1213 - diff_output_loss: 0.1139 - error_output_accuracy: 0.9222 - diff_output_mae: 0.2601 - val_loss: 0.3051 - val_error_output_loss: 0.1625 - val_diff_output_loss: 0.1426 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3064
# Epoch 57/100
# 14/14 [==============================] - 2s 111ms/step - loss: 0.2379 - error_output_loss: 0.1162 - diff_output_loss: 0.1217 - error_output_accuracy: 0.9363 - diff_output_mae: 0.2699 - val_loss: 0.3062 - val_error_output_loss: 0.1600 - val_diff_output_loss: 0.1463 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3099
# Epoch 58/100
# 14/14 [==============================] - 2s 112ms/step - loss: 0.2234 - error_output_loss: 0.1114 - diff_output_loss: 0.1120 - error_output_accuracy: 0.9434 - diff_output_mae: 0.2570 - val_loss: 0.3286 - val_error_output_loss: 0.1801 - val_diff_output_loss: 0.1484 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3111
# Epoch 59/100
# 14/14 [==============================] - 2s 122ms/step - loss: 0.2227 - error_output_loss: 0.1119 - diff_output_loss: 0.1109 - error_output_accuracy: 0.9269 - diff_output_mae: 0.2612 - val_loss: 0.2925 - val_error_output_loss: 0.1548 - val_diff_output_loss: 0.1377 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3036
# Epoch 60/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.2293 - error_output_loss: 0.1163 - diff_output_loss: 0.1129 - error_output_accuracy: 0.9222 - diff_output_mae: 0.2607 - val_loss: 0.2855 - val_error_output_loss: 0.1514 - val_diff_output_loss: 0.1341 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3053
# Epoch 61/100
# 14/14 [==============================] - 2s 132ms/step - loss: 0.2232 - error_output_loss: 0.1121 - diff_output_loss: 0.1111 - error_output_accuracy: 0.9222 - diff_output_mae: 0.2597 - val_loss: 0.3005 - val_error_output_loss: 0.1544 - val_diff_output_loss: 0.1461 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3094
# Epoch 62/100
# 14/14 [==============================] - 2s 128ms/step - loss: 0.2235 - error_output_loss: 0.1082 - diff_output_loss: 0.1153 - error_output_accuracy: 0.9434 - diff_output_mae: 0.2644 - val_loss: 0.3018 - val_error_output_loss: 0.1584 - val_diff_output_loss: 0.1434 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.2950
# Epoch 63/100
# 14/14 [==============================] - 2s 125ms/step - loss: 0.2046 - error_output_loss: 0.1034 - diff_output_loss: 0.1012 - error_output_accuracy: 0.9292 - diff_output_mae: 0.2498 - val_loss: 0.3078 - val_error_output_loss: 0.1695 - val_diff_output_loss: 0.1383 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3078
# Epoch 64/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.2033 - error_output_loss: 0.0952 - diff_output_loss: 0.1082 - error_output_accuracy: 0.9458 - diff_output_mae: 0.2621 - val_loss: 0.2841 - val_error_output_loss: 0.1602 - val_diff_output_loss: 0.1239 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2897
# Epoch 65/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1975 - error_output_loss: 0.0973 - diff_output_loss: 0.1002 - error_output_accuracy: 0.9434 - diff_output_mae: 0.2459 - val_loss: 0.2808 - val_error_output_loss: 0.1655 - val_diff_output_loss: 0.1154 - val_error_output_accuracy: 0.8037 - val_diff_output_mae: 0.2770
# Epoch 66/100
# 14/14 [==============================] - 2s 126ms/step - loss: 0.1879 - error_output_loss: 0.0909 - diff_output_loss: 0.0970 - error_output_accuracy: 0.9599 - diff_output_mae: 0.2434 - val_loss: 0.2826 - val_error_output_loss: 0.1582 - val_diff_output_loss: 0.1245 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.2869
# Epoch 67/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.2029 - error_output_loss: 0.0978 - diff_output_loss: 0.1051 - error_output_accuracy: 0.9458 - diff_output_mae: 0.2585 - val_loss: 0.3016 - val_error_output_loss: 0.1636 - val_diff_output_loss: 0.1381 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3064
# Epoch 68/100
# 14/14 [==============================] - 2s 133ms/step - loss: 0.2003 - error_output_loss: 0.0961 - diff_output_loss: 0.1042 - error_output_accuracy: 0.9340 - diff_output_mae: 0.2511 - val_loss: 0.2876 - val_error_output_loss: 0.1557 - val_diff_output_loss: 0.1319 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3000
# Epoch 69/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.1931 - error_output_loss: 0.0899 - diff_output_loss: 0.1032 - error_output_accuracy: 0.9387 - diff_output_mae: 0.2384 - val_loss: 0.2930 - val_error_output_loss: 0.1595 - val_diff_output_loss: 0.1336 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2980
# Epoch 70/100
# 14/14 [==============================] - 2s 126ms/step - loss: 0.1878 - error_output_loss: 0.0861 - diff_output_loss: 0.1017 - error_output_accuracy: 0.9528 - diff_output_mae: 0.2513 - val_loss: 0.2995 - val_error_output_loss: 0.1667 - val_diff_output_loss: 0.1328 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.2984
# Epoch 71/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.1822 - error_output_loss: 0.0884 - diff_output_loss: 0.0937 - error_output_accuracy: 0.9292 - diff_output_mae: 0.2378 - val_loss: 0.3312 - val_error_output_loss: 0.1691 - val_diff_output_loss: 0.1621 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3239
# Epoch 72/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.1885 - error_output_loss: 0.0856 - diff_output_loss: 0.1029 - error_output_accuracy: 0.9481 - diff_output_mae: 0.2474 - val_loss: 0.2926 - val_error_output_loss: 0.1638 - val_diff_output_loss: 0.1288 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2968
# Epoch 73/100
# 14/14 [==============================] - 2s 123ms/step - loss: 0.1685 - error_output_loss: 0.0852 - diff_output_loss: 0.0834 - error_output_accuracy: 0.9552 - diff_output_mae: 0.2229 - val_loss: 0.3154 - val_error_output_loss: 0.1652 - val_diff_output_loss: 0.1503 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3124
# Epoch 74/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.1750 - error_output_loss: 0.0833 - diff_output_loss: 0.0917 - error_output_accuracy: 0.9575 - diff_output_mae: 0.2394 - val_loss: 0.3040 - val_error_output_loss: 0.1605 - val_diff_output_loss: 0.1436 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.3039
# Epoch 75/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.1783 - error_output_loss: 0.0809 - diff_output_loss: 0.0974 - error_output_accuracy: 0.9623 - diff_output_mae: 0.2466 - val_loss: 0.3063 - val_error_output_loss: 0.1605 - val_diff_output_loss: 0.1458 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3110
# Epoch 76/100
# 14/14 [==============================] - 2s 127ms/step - loss: 0.1622 - error_output_loss: 0.0797 - diff_output_loss: 0.0825 - error_output_accuracy: 0.9575 - diff_output_mae: 0.2305 - val_loss: 0.2924 - val_error_output_loss: 0.1590 - val_diff_output_loss: 0.1334 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.2985
# Epoch 77/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.1611 - error_output_loss: 0.0801 - diff_output_loss: 0.0810 - error_output_accuracy: 0.9505 - diff_output_mae: 0.2217 - val_loss: 0.3100 - val_error_output_loss: 0.1679 - val_diff_output_loss: 0.1421 - val_error_output_accuracy: 0.8037 - val_diff_output_mae: 0.3060
# Epoch 78/100
# 14/14 [==============================] - 2s 124ms/step - loss: 0.1679 - error_output_loss: 0.0735 - diff_output_loss: 0.0944 - error_output_accuracy: 0.9693 - diff_output_mae: 0.2303 - val_loss: 0.3107 - val_error_output_loss: 0.1649 - val_diff_output_loss: 0.1458 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3067
# Epoch 79/100
# 14/14 [==============================] - 2s 125ms/step - loss: 0.1822 - error_output_loss: 0.0731 - diff_output_loss: 0.1090 - error_output_accuracy: 0.9646 - diff_output_mae: 0.2532 - val_loss: 0.3056 - val_error_output_loss: 0.1537 - val_diff_output_loss: 0.1519 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3151
# Epoch 80/100
# 14/14 [==============================] - 2s 134ms/step - loss: 0.1622 - error_output_loss: 0.0707 - diff_output_loss: 0.0915 - error_output_accuracy: 0.9552 - diff_output_mae: 0.2381 - val_loss: 0.3111 - val_error_output_loss: 0.1525 - val_diff_output_loss: 0.1585 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3306
# 4/4 [==============================] - 4s 19ms/step
#
#  ---Error Type Classification Report---
#                                precision    recall  f1-score   support
#
#           Addition of Letters       1.00      1.00      1.00        23
# Letter-Phoneme Correspondence       0.60      0.56      0.58        16
#           Omission of Letters       1.00      0.77      0.87        22
#                Silent Letters       0.71      0.71      0.71        21
#                Transpositions       1.00      0.80      0.89        25
#
#                     micro avg       0.88      0.79      0.83       107
#                     macro avg       0.86      0.77      0.81       107
#                  weighted avg       0.88      0.79      0.83       107
#                   samples avg       0.78      0.79      0.78       107
#
#
#  ---Confusion Matrices---
#  ---Difficulty Prediction---
# Validation Difficulty MAE: 0.28
# Model trained and saved!

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
tutor_loaded.model.summary()
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  embedding (Embedding)       (None, 8, 128)               3712      ['input_1[0][0]']
#
#  bidirectional (Bidirection  (None, 8, 1024)              2625536   ['embedding[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 8, 512)               2623488   ['bidirectional[0][0]']
#  onal)
#
#  global_max_pooling1d (Glob  (None, 512)                  0         ['bidirectional_1[0][0]']
#  alMaxPooling1D)
#
#  input_2 (InputLayer)        [(None, 12)]                 0         []
#
#  concatenate (Concatenate)   (None, 524)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense (Dense)               (None, 128)                  67200     ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  error_output (Dense)        (None, 5)                    645       ['dropout[0][0]']
#
#  diff_output (Dense)         (None, 1)                    129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5320710 (20.30 MB)
# Trainable params: 5320710 (20.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
test_words = [
    'nife',
    'rite',
    'mountan',
    'naw',
    'freind',
    'fone',
    'sykology',
    'aline',
    'safary',
    'kitcehn'
]

results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_confidence': 0.0, 'total_difficulty': 0.0})

for result in results:
    if not result['correct']:
        error_type = result['max_confidence_type']
        grouped_results[error_type]['count'] += 1
        grouped_results[error_type]['total_score_change'] += result['score_change']
        grouped_results[error_type]['words'].append(result['word'])
        grouped_results[error_type]['avg_confidence'] += result['confidence']
        grouped_results[error_type]['total_difficulty'] += result['predicted_difficulty']

print("\n=== Results Analysis by Error Type ===")
for error_type, data in grouped_results.items():
    if data['count'] > 0:
        data['avg_confidence'] /= data['count']
        data['avg_difficulty'] = data['total_difficulty'] / data['count']
        rounded_difficulty_level = round(data['avg_difficulty'])

        print(f"Error Type: {error_type}")
        print(f"  Count: {data['count']}")
        print(f"  Average Confidence: {data['avg_confidence']:.2%}")
        print(f"  Average Difficulty: {data['avg_difficulty']:.2f}")
        print(f"  Words: {', '.join(data['words'])}")

        if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
            error_type_words = tutor_loaded.processor.df[
                (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
                (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
            ]

            if not error_type_words.empty:
                new_words = error_type_words[~error_type_words['Incorrect_Word'].isin(data['words'])]

                if not new_words.empty:
                    suggested_words = new_words['Incorrect_Word'].sample(min(5, len(new_words))).tolist()
                    print(f"  Suggested Words (Difficulty {rounded_difficulty_level}):")
                    for i, word in enumerate(suggested_words, 1):
                        difficulty = tutor_loaded.processor.get_difficulty(word)
                        correct_word = error_type_words[error_type_words['Incorrect_Word'] == word]['Correct_Word'].iloc[0]
                        print(f"    {i}. {word} (correct: {correct_word})")


if grouped_results:
    error_types = list(grouped_results.keys())
    error_counts = [grouped_results[et]['count'] for et in error_types]
    avg_confidences = [grouped_results[et]['avg_confidence'] for et in error_types]

    fig, ax1 = plt.subplots(figsize=(12, 6))

    x = np.arange(len(error_types))
    bars = ax1.bar(x, error_counts, width=0.6, color='skyblue', label='Count')
    ax1.set_xlabel('Error Types')
    ax1.set_ylabel('Count')
    ax1.set_title('Error Type Distribution with Confidence')
    ax1.set_xticks(x)
    ax1.set_xticklabels(error_types, rotation=45, ha='right')

    ax2 = ax1.twinx()
    ax2.plot(x, avg_confidences, 'ro-', label='Confidence')
    ax2.set_ylabel('Average Confidence')
    ax2.set_ylim([0, 1])

    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper left')

    plt.tight_layout()
    plt.savefig('error_analysis.png')
    plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
#
# Word: nife
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (53.64%), Silent Letters (67.13%)
# Max Confidence Error Type: Silent Letters (67.13%)
# Predicted Difficulty: 2.47 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 32ms/step
#
# Word: rite
# Status: ✗ Incorrect
# Error Types: Silent Letters (90.99%)
# Max Confidence Error Type: Silent Letters (90.99%)
# Predicted Difficulty: 2.32 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: mountan
# Status: ✗ Incorrect
# Error Types: Omission of Letters (65.11%)
# Max Confidence Error Type: Omission of Letters (65.11%)
# Predicted Difficulty: 3.81 | Actual Difficulty: 4
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: naw
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (46.00%), Silent Letters (68.77%)
# Max Confidence Error Type: Silent Letters (68.77%)
# Predicted Difficulty: 1.93 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 31ms/step
#
# Word: freind
# Status: ✗ Incorrect
# Error Types: Transpositions (69.91%)
# Max Confidence Error Type: Transpositions (69.91%)
# Predicted Difficulty: 2.59 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 30ms/step
#
# Word: fone
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (81.69%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (81.69%)
# Predicted Difficulty: 2.26 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: sykology
# Status: ✗ Incorrect
# Error Types: Unknown (17.09%)
# Max Confidence Error Type: Omission of Letters (17.09%)
# Predicted Difficulty: 2.82 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 28ms/step
#
# Word: aline
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (36.58%), Silent Letters (36.52%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (36.58%)
# Predicted Difficulty: 2.4 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 30ms/step
#
# Word: safary
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (94.71%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (94.71%)
# Predicted Difficulty: 2.85 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 28ms/step
#
# Word: kitcehn
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (44.96%), Transpositions (60.92%)
# Max Confidence Error Type: Transpositions (60.92%)
# Predicted Difficulty: 2.93 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
#
# === Results Analysis by Error Type ===
# Error Type: Silent Letters
#   Count: 3
#   Average Confidence: 75.63%
#   Average Difficulty: 2.24
#   Words: nife, rite, naw
#   Suggested Words (Difficulty 2):
#     1. wistle (correct: whistle)
#     2. wom (correct: womb)
#     3. lim (correct: limb)
#     4. plum (correct: plumb)
#     5. tom (correct: tomb)
# Error Type: Omission of Letters
#   Count: 2
#   Average Confidence: 41.10%
#   Average Difficulty: 3.31
#   Words: mountan, sykology
#   Suggested Words (Difficulty 3):
#     1. ofice (correct: office)
#     2. yelow (correct: yellow)
#     3. super (correct: supper)
#     4. carot (correct: carrot)
#     5. siting (correct: sitting)
# Error Type: Transpositions
#   Count: 2
#   Average Confidence: 65.42%
#   Average Difficulty: 2.76
#   Words: freind, kitcehn
#   Suggested Words (Difficulty 3):
#     1. sprign (correct: spring)
#     2. windwo (correct: window)
#     3. teahcer (correct: teacher)
#     4. scohol (correct: school)
#     5. pumpikn (correct: pumpkin)
# Error Type: Letter-Phoneme Correspondence
#   Count: 3
#   Average Confidence: 70.99%
#   Average Difficulty: 2.50
#   Words: fone, aline, safary
#   Suggested Words (Difficulty 3):
#     1. speshul (correct: special)
#     2. stashun (correct: station)
#     3. moshun (correct: motion)
#     4. skool (correct: school)
#     5. tot (correct: taught)
