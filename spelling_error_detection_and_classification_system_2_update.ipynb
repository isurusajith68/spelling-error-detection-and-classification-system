# %%
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("TensorFlow version: ", tf.__version__)
# Out:
# Num GPUs Available:  0
# Num CPUs Available:  1
# TensorFlow version:  2.15.0

# %%
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 188      science         syence  Letter-Phoneme Correspondence             7
# 314      physics         fiziks  Letter-Phoneme Correspondence             7
# 412         debt          debtt            Addition of Letters             4
# 366        plane          palne                 Transpositions             5
# 211        aisle          aisel  Letter-Phoneme Correspondence             5
# 423        badge          badje  Letter-Phoneme Correspondence             5
# 33          comb            com                 Silent Letters             4
# 425         plug         pllugg            Addition of Letters             4
# 265         hour           howr                 Transpositions             4
# 294       design         desine  Letter-Phoneme Correspondence             6
# 240      blanket        blnaket                 Transpositions             7
# 225      thunder        thnuder                 Transpositions             7
# 71        mirror          miror            Omission of Letters             6
# 67     chemistry       kemistry  Letter-Phoneme Correspondence             9
# 152       answer         asnwer                 Transpositions             6
# 363        knock            nok                 Silent Letters             5
# 262        chaos           kaoz  Letter-Phoneme Correspondence             5
# 419       knight          knigt                 Transpositions             6
# 100       pepper           pepr            Omission of Letters             6
# 255       cradle         cardle                 Transpositions             6
#
#      Difficulty_Level
# 188                 3
# 314                 3
# 412                 2
# 366                 2
# 211                 2
# 423                 2
# 33                  2
# 425                 2
# 265                 2
# 294                 3
# 240                 3
# 225                 3
# 71                  3
# 67                  4
# 152                 3
# 363                 2
# 262                 2
# 419                 3
# 100                 3
# 255                 3

# %%
class DataProcessor:
    def __init__(self, dataset_path):
        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)
        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())
        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))
        self._create_char_encoding()
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}
        self.max_difficulty = self.df['Difficulty_Level'].max()
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")

    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word
        edits = jellyfish.levenshtein_distance(word, correct_word)
        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)
        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)
        phoneme_mismatch_flag = jellyfish.metaphone(word) != jellyfish.metaphone(correct_word) and not transposition_flag
        silent_letter_flag = edits > 0 and jellyfish.soundex(word) == jellyfish.soundex(correct_word) and not omission_flag
        return np.array([edits, transposition_flag, omission_flag, addition_flag, phoneme_mismatch_flag, silent_letter_flag], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(6,))
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(512, return_sequences=True, dropout=0.2))(x)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.2))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=15, restore_best_weights=True),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()}
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])
        error_acc = np.mean([np.all(pred > 0.5) == true for pred, true in zip(error_preds, self.y_val_error)])
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}
            # print(f"Debug - Word: {word}, Error Probabilities: {error_proba[0]}")

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences if not correct else {'Correct': 1.0},
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# Epoch 1/100
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From d:\machine learning\spelling error detection and classification system\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 11/11 [==============================] - 20s 582ms/step - loss: 4.5974 - error_output_loss: 0.7279 - diff_output_loss: 3.8694 - error_output_accuracy: 0.1727 - diff_output_mae: 1.6852 - val_loss: 1.8950 - val_error_output_loss: 0.6999 - val_diff_output_loss: 1.1950 - val_error_output_accuracy: 0.1807 - val_diff_output_mae: 0.9962
# Epoch 2/100
# 11/11 [==============================] - 2s 154ms/step - loss: 1.6040 - error_output_loss: 0.6620 - diff_output_loss: 0.9420 - error_output_accuracy: 0.1727 - diff_output_mae: 0.8181 - val_loss: 1.0334 - val_error_output_loss: 0.5927 - val_diff_output_loss: 0.4407 - val_error_output_accuracy: 0.2530 - val_diff_output_mae: 0.5597
# Epoch 3/100
# 11/11 [==============================] - 2s 156ms/step - loss: 0.9659 - error_output_loss: 0.5865 - diff_output_loss: 0.3794 - error_output_accuracy: 0.2273 - diff_output_mae: 0.5049 - val_loss: 0.7975 - val_error_output_loss: 0.5445 - val_diff_output_loss: 0.2530 - val_error_output_accuracy: 0.2530 - val_diff_output_mae: 0.4042
# Epoch 4/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.8210 - error_output_loss: 0.5265 - diff_output_loss: 0.2945 - error_output_accuracy: 0.2394 - diff_output_mae: 0.4317 - val_loss: 0.6892 - val_error_output_loss: 0.5080 - val_diff_output_loss: 0.1812 - val_error_output_accuracy: 0.2530 - val_diff_output_mae: 0.3361
# Epoch 5/100
# 11/11 [==============================] - 2s 151ms/step - loss: 0.7498 - error_output_loss: 0.5071 - diff_output_loss: 0.2428 - error_output_accuracy: 0.2848 - diff_output_mae: 0.3946 - val_loss: 0.6532 - val_error_output_loss: 0.4949 - val_diff_output_loss: 0.1583 - val_error_output_accuracy: 0.2289 - val_diff_output_mae: 0.3192
# Epoch 6/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.7258 - error_output_loss: 0.4970 - diff_output_loss: 0.2289 - error_output_accuracy: 0.2909 - diff_output_mae: 0.3913 - val_loss: 0.6371 - val_error_output_loss: 0.4906 - val_diff_output_loss: 0.1466 - val_error_output_accuracy: 0.3976 - val_diff_output_mae: 0.3091
# Epoch 7/100
# 11/11 [==============================] - 2s 156ms/step - loss: 0.6947 - error_output_loss: 0.4966 - diff_output_loss: 0.1981 - error_output_accuracy: 0.2848 - diff_output_mae: 0.3695 - val_loss: 0.6329 - val_error_output_loss: 0.4884 - val_diff_output_loss: 0.1446 - val_error_output_accuracy: 0.3976 - val_diff_output_mae: 0.3095
# Epoch 8/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.6756 - error_output_loss: 0.4927 - diff_output_loss: 0.1830 - error_output_accuracy: 0.3121 - diff_output_mae: 0.3498 - val_loss: 0.6244 - val_error_output_loss: 0.4857 - val_diff_output_loss: 0.1388 - val_error_output_accuracy: 0.4337 - val_diff_output_mae: 0.3044
# Epoch 9/100
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6680 - error_output_loss: 0.4902 - diff_output_loss: 0.1777 - error_output_accuracy: 0.3091 - diff_output_mae: 0.3361 - val_loss: 0.6248 - val_error_output_loss: 0.4836 - val_diff_output_loss: 0.1412 - val_error_output_accuracy: 0.4217 - val_diff_output_mae: 0.3045
# Epoch 10/100
# 11/11 [==============================] - 1s 119ms/step - loss: 0.6530 - error_output_loss: 0.4897 - diff_output_loss: 0.1633 - error_output_accuracy: 0.3364 - diff_output_mae: 0.3264 - val_loss: 0.6549 - val_error_output_loss: 0.4816 - val_diff_output_loss: 0.1733 - val_error_output_accuracy: 0.4578 - val_diff_output_mae: 0.3405
# Epoch 11/100
# 11/11 [==============================] - 1s 110ms/step - loss: 0.6598 - error_output_loss: 0.4851 - diff_output_loss: 0.1747 - error_output_accuracy: 0.3697 - diff_output_mae: 0.3454 - val_loss: 0.6330 - val_error_output_loss: 0.4773 - val_diff_output_loss: 0.1557 - val_error_output_accuracy: 0.4458 - val_diff_output_mae: 0.3238
# Epoch 12/100
# 11/11 [==============================] - 2s 141ms/step - loss: 0.6335 - error_output_loss: 0.4798 - diff_output_loss: 0.1537 - error_output_accuracy: 0.3788 - diff_output_mae: 0.3190 - val_loss: 0.5927 - val_error_output_loss: 0.4734 - val_diff_output_loss: 0.1193 - val_error_output_accuracy: 0.5301 - val_diff_output_mae: 0.2858
# Epoch 13/100
# 11/11 [==============================] - 2s 151ms/step - loss: 0.6279 - error_output_loss: 0.4780 - diff_output_loss: 0.1499 - error_output_accuracy: 0.3636 - diff_output_mae: 0.3147 - val_loss: 0.5758 - val_error_output_loss: 0.4683 - val_diff_output_loss: 0.1074 - val_error_output_accuracy: 0.3855 - val_diff_output_mae: 0.2686
# Epoch 14/100
# 11/11 [==============================] - 2s 195ms/step - loss: 0.6339 - error_output_loss: 0.4724 - diff_output_loss: 0.1615 - error_output_accuracy: 0.4152 - diff_output_mae: 0.3170 - val_loss: 0.5721 - val_error_output_loss: 0.4649 - val_diff_output_loss: 0.1072 - val_error_output_accuracy: 0.5301 - val_diff_output_mae: 0.2681
# Epoch 15/100
# 11/11 [==============================] - 2s 180ms/step - loss: 0.6307 - error_output_loss: 0.4634 - diff_output_loss: 0.1673 - error_output_accuracy: 0.4333 - diff_output_mae: 0.3235 - val_loss: 0.5575 - val_error_output_loss: 0.4609 - val_diff_output_loss: 0.0966 - val_error_output_accuracy: 0.5422 - val_diff_output_mae: 0.2605
# Epoch 16/100
# 11/11 [==============================] - 2s 181ms/step - loss: 0.6045 - error_output_loss: 0.4652 - diff_output_loss: 0.1393 - error_output_accuracy: 0.4788 - diff_output_mae: 0.3008 - val_loss: 0.5477 - val_error_output_loss: 0.4562 - val_diff_output_loss: 0.0915 - val_error_output_accuracy: 0.5542 - val_diff_output_mae: 0.2520
# Epoch 17/100
# 11/11 [==============================] - 2s 171ms/step - loss: 0.5811 - error_output_loss: 0.4611 - diff_output_loss: 0.1201 - error_output_accuracy: 0.4697 - diff_output_mae: 0.2809 - val_loss: 0.5476 - val_error_output_loss: 0.4532 - val_diff_output_loss: 0.0944 - val_error_output_accuracy: 0.5422 - val_diff_output_mae: 0.2616
# Epoch 18/100
# 11/11 [==============================] - 2s 165ms/step - loss: 0.5938 - error_output_loss: 0.4581 - diff_output_loss: 0.1357 - error_output_accuracy: 0.4758 - diff_output_mae: 0.2947 - val_loss: 0.5407 - val_error_output_loss: 0.4488 - val_diff_output_loss: 0.0919 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2467
# Epoch 19/100
# 11/11 [==============================] - 2s 170ms/step - loss: 0.5821 - error_output_loss: 0.4502 - diff_output_loss: 0.1319 - error_output_accuracy: 0.4909 - diff_output_mae: 0.2944 - val_loss: 0.5371 - val_error_output_loss: 0.4451 - val_diff_output_loss: 0.0920 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2546
# Epoch 20/100
# 11/11 [==============================] - 2s 176ms/step - loss: 0.5801 - error_output_loss: 0.4494 - diff_output_loss: 0.1307 - error_output_accuracy: 0.5394 - diff_output_mae: 0.2892 - val_loss: 0.5294 - val_error_output_loss: 0.4403 - val_diff_output_loss: 0.0891 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2492
# Epoch 21/100
# 11/11 [==============================] - 2s 179ms/step - loss: 0.5687 - error_output_loss: 0.4452 - diff_output_loss: 0.1235 - error_output_accuracy: 0.4909 - diff_output_mae: 0.2786 - val_loss: 0.5242 - val_error_output_loss: 0.4359 - val_diff_output_loss: 0.0883 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2513
# Epoch 22/100
# 11/11 [==============================] - 2s 167ms/step - loss: 0.5457 - error_output_loss: 0.4405 - diff_output_loss: 0.1052 - error_output_accuracy: 0.5182 - diff_output_mae: 0.2632 - val_loss: 0.5147 - val_error_output_loss: 0.4296 - val_diff_output_loss: 0.0851 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2405
# Epoch 23/100
# 11/11 [==============================] - 2s 168ms/step - loss: 0.5458 - error_output_loss: 0.4358 - diff_output_loss: 0.1100 - error_output_accuracy: 0.5273 - diff_output_mae: 0.2725 - val_loss: 0.5085 - val_error_output_loss: 0.4248 - val_diff_output_loss: 0.0837 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2418
# Epoch 24/100
# 11/11 [==============================] - 2s 158ms/step - loss: 0.5661 - error_output_loss: 0.4321 - diff_output_loss: 0.1340 - error_output_accuracy: 0.5273 - diff_output_mae: 0.2964 - val_loss: 0.5040 - val_error_output_loss: 0.4193 - val_diff_output_loss: 0.0847 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2446
# Epoch 25/100
# 11/11 [==============================] - 1s 134ms/step - loss: 0.5487 - error_output_loss: 0.4270 - diff_output_loss: 0.1218 - error_output_accuracy: 0.4970 - diff_output_mae: 0.2749 - val_loss: 0.5066 - val_error_output_loss: 0.4142 - val_diff_output_loss: 0.0924 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2451
# Epoch 26/100
# 11/11 [==============================] - 2s 180ms/step - loss: 0.5642 - error_output_loss: 0.4160 - diff_output_loss: 0.1481 - error_output_accuracy: 0.5485 - diff_output_mae: 0.3084 - val_loss: 0.4923 - val_error_output_loss: 0.4112 - val_diff_output_loss: 0.0811 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2386
# Epoch 27/100
# 11/11 [==============================] - 2s 141ms/step - loss: 0.5509 - error_output_loss: 0.4152 - diff_output_loss: 0.1358 - error_output_accuracy: 0.5485 - diff_output_mae: 0.2951 - val_loss: 0.5172 - val_error_output_loss: 0.4043 - val_diff_output_loss: 0.1129 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2839
# Epoch 28/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.5703 - error_output_loss: 0.4094 - diff_output_loss: 0.1609 - error_output_accuracy: 0.5636 - diff_output_mae: 0.3208 - val_loss: 0.5270 - val_error_output_loss: 0.3999 - val_diff_output_loss: 0.1271 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2984
# Epoch 29/100
# 11/11 [==============================] - 2s 165ms/step - loss: 0.5126 - error_output_loss: 0.4053 - diff_output_loss: 0.1073 - error_output_accuracy: 0.5727 - diff_output_mae: 0.2670 - val_loss: 0.4846 - val_error_output_loss: 0.3954 - val_diff_output_loss: 0.0891 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2579
# Epoch 30/100
# 11/11 [==============================] - 2s 167ms/step - loss: 0.5244 - error_output_loss: 0.3989 - diff_output_loss: 0.1255 - error_output_accuracy: 0.5970 - diff_output_mae: 0.2846 - val_loss: 0.4809 - val_error_output_loss: 0.3918 - val_diff_output_loss: 0.0891 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2589
# Epoch 31/100
# 11/11 [==============================] - 2s 139ms/step - loss: 0.5108 - error_output_loss: 0.3994 - diff_output_loss: 0.1115 - error_output_accuracy: 0.5788 - diff_output_mae: 0.2751 - val_loss: 0.4840 - val_error_output_loss: 0.3869 - val_diff_output_loss: 0.0971 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2698
# Epoch 32/100
# 11/11 [==============================] - 2s 171ms/step - loss: 0.5129 - error_output_loss: 0.3931 - diff_output_loss: 0.1198 - error_output_accuracy: 0.5848 - diff_output_mae: 0.2795 - val_loss: 0.4705 - val_error_output_loss: 0.3809 - val_diff_output_loss: 0.0896 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2591
# Epoch 33/100
# 11/11 [==============================] - 2s 181ms/step - loss: 0.4915 - error_output_loss: 0.3854 - diff_output_loss: 0.1061 - error_output_accuracy: 0.5758 - diff_output_mae: 0.2568 - val_loss: 0.4555 - val_error_output_loss: 0.3761 - val_diff_output_loss: 0.0794 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2336
# Epoch 34/100
# 11/11 [==============================] - 2s 164ms/step - loss: 0.4861 - error_output_loss: 0.3835 - diff_output_loss: 0.1026 - error_output_accuracy: 0.5818 - diff_output_mae: 0.2580 - val_loss: 0.4492 - val_error_output_loss: 0.3709 - val_diff_output_loss: 0.0783 - val_error_output_accuracy: 0.5904 - val_diff_output_mae: 0.2386
# Epoch 35/100
# 11/11 [==============================] - 2s 166ms/step - loss: 0.4810 - error_output_loss: 0.3785 - diff_output_loss: 0.1025 - error_output_accuracy: 0.5939 - diff_output_mae: 0.2669 - val_loss: 0.4435 - val_error_output_loss: 0.3655 - val_diff_output_loss: 0.0779 - val_error_output_accuracy: 0.5783 - val_diff_output_mae: 0.2331
# Epoch 36/100
# 11/11 [==============================] - 2s 167ms/step - loss: 0.4786 - error_output_loss: 0.3689 - diff_output_loss: 0.1096 - error_output_accuracy: 0.6273 - diff_output_mae: 0.2632 - val_loss: 0.4371 - val_error_output_loss: 0.3583 - val_diff_output_loss: 0.0788 - val_error_output_accuracy: 0.6265 - val_diff_output_mae: 0.2406
# Epoch 37/100
# 11/11 [==============================] - 1s 135ms/step - loss: 0.4767 - error_output_loss: 0.3629 - diff_output_loss: 0.1138 - error_output_accuracy: 0.6212 - diff_output_mae: 0.2648 - val_loss: 0.4685 - val_error_output_loss: 0.3532 - val_diff_output_loss: 0.1153 - val_error_output_accuracy: 0.6506 - val_diff_output_mae: 0.2832
# Epoch 38/100
# 11/11 [==============================] - 2s 173ms/step - loss: 0.4935 - error_output_loss: 0.3562 - diff_output_loss: 0.1373 - error_output_accuracy: 0.6061 - diff_output_mae: 0.2896 - val_loss: 0.4218 - val_error_output_loss: 0.3504 - val_diff_output_loss: 0.0714 - val_error_output_accuracy: 0.6024 - val_diff_output_mae: 0.2289
# Epoch 39/100
# 11/11 [==============================] - 2s 179ms/step - loss: 0.4688 - error_output_loss: 0.3544 - diff_output_loss: 0.1144 - error_output_accuracy: 0.6212 - diff_output_mae: 0.2713 - val_loss: 0.4106 - val_error_output_loss: 0.3407 - val_diff_output_loss: 0.0699 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2263
# Epoch 40/100
# 11/11 [==============================] - 2s 161ms/step - loss: 0.4583 - error_output_loss: 0.3429 - diff_output_loss: 0.1154 - error_output_accuracy: 0.6636 - diff_output_mae: 0.2722 - val_loss: 0.4083 - val_error_output_loss: 0.3372 - val_diff_output_loss: 0.0710 - val_error_output_accuracy: 0.6506 - val_diff_output_mae: 0.2241
# Epoch 41/100
# 11/11 [==============================] - 2s 167ms/step - loss: 0.4446 - error_output_loss: 0.3335 - diff_output_loss: 0.1110 - error_output_accuracy: 0.6818 - diff_output_mae: 0.2603 - val_loss: 0.4052 - val_error_output_loss: 0.3353 - val_diff_output_loss: 0.0698 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2209
# Epoch 42/100
# 11/11 [==============================] - 1s 135ms/step - loss: 0.4479 - error_output_loss: 0.3380 - diff_output_loss: 0.1099 - error_output_accuracy: 0.6485 - diff_output_mae: 0.2651 - val_loss: 0.4167 - val_error_output_loss: 0.3357 - val_diff_output_loss: 0.0810 - val_error_output_accuracy: 0.6145 - val_diff_output_mae: 0.2282
# Epoch 43/100
# 11/11 [==============================] - 2s 176ms/step - loss: 0.4625 - error_output_loss: 0.3374 - diff_output_loss: 0.1252 - error_output_accuracy: 0.6515 - diff_output_mae: 0.2776 - val_loss: 0.4016 - val_error_output_loss: 0.3321 - val_diff_output_loss: 0.0695 - val_error_output_accuracy: 0.6506 - val_diff_output_mae: 0.2205
# Epoch 44/100
# 11/11 [==============================] - 2s 139ms/step - loss: 0.4353 - error_output_loss: 0.3245 - diff_output_loss: 0.1108 - error_output_accuracy: 0.6939 - diff_output_mae: 0.2644 - val_loss: 0.4204 - val_error_output_loss: 0.3390 - val_diff_output_loss: 0.0814 - val_error_output_accuracy: 0.6627 - val_diff_output_mae: 0.2456
# Epoch 45/100
# 11/11 [==============================] - 2s 181ms/step - loss: 0.4335 - error_output_loss: 0.3229 - diff_output_loss: 0.1106 - error_output_accuracy: 0.6697 - diff_output_mae: 0.2698 - val_loss: 0.3905 - val_error_output_loss: 0.3187 - val_diff_output_loss: 0.0718 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2150
# Epoch 46/100
# 11/11 [==============================] - 2s 142ms/step - loss: 0.4434 - error_output_loss: 0.3139 - diff_output_loss: 0.1295 - error_output_accuracy: 0.6697 - diff_output_mae: 0.2813 - val_loss: 0.4266 - val_error_output_loss: 0.3236 - val_diff_output_loss: 0.1029 - val_error_output_accuracy: 0.6506 - val_diff_output_mae: 0.2499
# Epoch 47/100
# 11/11 [==============================] - 2s 161ms/step - loss: 0.4314 - error_output_loss: 0.3164 - diff_output_loss: 0.1150 - error_output_accuracy: 0.6909 - diff_output_mae: 0.2764 - val_loss: 0.3826 - val_error_output_loss: 0.3138 - val_diff_output_loss: 0.0689 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2207
# Epoch 48/100
# 11/11 [==============================] - 1s 132ms/step - loss: 0.4250 - error_output_loss: 0.3015 - diff_output_loss: 0.1235 - error_output_accuracy: 0.7273 - diff_output_mae: 0.2844 - val_loss: 0.3883 - val_error_output_loss: 0.3052 - val_diff_output_loss: 0.0831 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2448
# Epoch 49/100
# 11/11 [==============================] - 2s 149ms/step - loss: 0.4454 - error_output_loss: 0.3092 - diff_output_loss: 0.1362 - error_output_accuracy: 0.7061 - diff_output_mae: 0.2860 - val_loss: 0.3850 - val_error_output_loss: 0.2948 - val_diff_output_loss: 0.0901 - val_error_output_accuracy: 0.7590 - val_diff_output_mae: 0.2468
# Epoch 50/100
# 11/11 [==============================] - 2s 175ms/step - loss: 0.4218 - error_output_loss: 0.2990 - diff_output_loss: 0.1228 - error_output_accuracy: 0.7061 - diff_output_mae: 0.2772 - val_loss: 0.3713 - val_error_output_loss: 0.2881 - val_diff_output_loss: 0.0832 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2395
# Epoch 51/100
# 11/11 [==============================] - 2s 179ms/step - loss: 0.4135 - error_output_loss: 0.3021 - diff_output_loss: 0.1114 - error_output_accuracy: 0.7121 - diff_output_mae: 0.2577 - val_loss: 0.3697 - val_error_output_loss: 0.2968 - val_diff_output_loss: 0.0730 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2355
# Epoch 52/100
# 11/11 [==============================] - 2s 173ms/step - loss: 0.4056 - error_output_loss: 0.2910 - diff_output_loss: 0.1147 - error_output_accuracy: 0.7182 - diff_output_mae: 0.2722 - val_loss: 0.3588 - val_error_output_loss: 0.2944 - val_diff_output_loss: 0.0644 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2120
# Epoch 53/100
# 11/11 [==============================] - 1s 136ms/step - loss: 0.4153 - error_output_loss: 0.2887 - diff_output_loss: 0.1266 - error_output_accuracy: 0.7273 - diff_output_mae: 0.2838 - val_loss: 0.3738 - val_error_output_loss: 0.2974 - val_diff_output_loss: 0.0764 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2112
# Epoch 54/100
# 11/11 [==============================] - 2s 142ms/step - loss: 0.4002 - error_output_loss: 0.2874 - diff_output_loss: 0.1128 - error_output_accuracy: 0.7121 - diff_output_mae: 0.2699 - val_loss: 0.3618 - val_error_output_loss: 0.2932 - val_diff_output_loss: 0.0686 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2090
# Epoch 55/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.4022 - error_output_loss: 0.2860 - diff_output_loss: 0.1163 - error_output_accuracy: 0.7182 - diff_output_mae: 0.2627 - val_loss: 0.3596 - val_error_output_loss: 0.2895 - val_diff_output_loss: 0.0701 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2211
# Epoch 56/100
# 11/11 [==============================] - 2s 153ms/step - loss: 0.3954 - error_output_loss: 0.2907 - diff_output_loss: 0.1047 - error_output_accuracy: 0.7000 - diff_output_mae: 0.2609 - val_loss: 0.3756 - val_error_output_loss: 0.2998 - val_diff_output_loss: 0.0758 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2320
# Epoch 57/100
# 11/11 [==============================] - 2s 137ms/step - loss: 0.3880 - error_output_loss: 0.2724 - diff_output_loss: 0.1156 - error_output_accuracy: 0.7515 - diff_output_mae: 0.2684 - val_loss: 0.3612 - val_error_output_loss: 0.2893 - val_diff_output_loss: 0.0718 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2156
# Epoch 58/100
# 11/11 [==============================] - 1s 132ms/step - loss: 0.3674 - error_output_loss: 0.2719 - diff_output_loss: 0.0954 - error_output_accuracy: 0.7485 - diff_output_mae: 0.2457 - val_loss: 0.3762 - val_error_output_loss: 0.2952 - val_diff_output_loss: 0.0810 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2182
# Epoch 59/100
# 11/11 [==============================] - 1s 128ms/step - loss: 0.3820 - error_output_loss: 0.2717 - diff_output_loss: 0.1103 - error_output_accuracy: 0.7394 - diff_output_mae: 0.2613 - val_loss: 0.3757 - val_error_output_loss: 0.2871 - val_diff_output_loss: 0.0886 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2558
# Epoch 60/100
# 11/11 [==============================] - 1s 125ms/step - loss: 0.3534 - error_output_loss: 0.2605 - diff_output_loss: 0.0930 - error_output_accuracy: 0.7667 - diff_output_mae: 0.2445 - val_loss: 0.3976 - val_error_output_loss: 0.2821 - val_diff_output_loss: 0.1155 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2821
# Epoch 61/100
# 11/11 [==============================] - 2s 132ms/step - loss: 0.4102 - error_output_loss: 0.2664 - diff_output_loss: 0.1438 - error_output_accuracy: 0.7394 - diff_output_mae: 0.3019 - val_loss: 0.4016 - val_error_output_loss: 0.2850 - val_diff_output_loss: 0.1166 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2839
# Epoch 62/100
# 11/11 [==============================] - 2s 141ms/step - loss: 0.3724 - error_output_loss: 0.2506 - diff_output_loss: 0.1217 - error_output_accuracy: 0.7576 - diff_output_mae: 0.2734 - val_loss: 0.4137 - val_error_output_loss: 0.2914 - val_diff_output_loss: 0.1224 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2909
# Epoch 63/100
# 11/11 [==============================] - 2s 142ms/step - loss: 0.3748 - error_output_loss: 0.2558 - diff_output_loss: 0.1190 - error_output_accuracy: 0.7485 - diff_output_mae: 0.2754 - val_loss: 0.4116 - val_error_output_loss: 0.3164 - val_diff_output_loss: 0.0953 - val_error_output_accuracy: 0.7349 - val_diff_output_mae: 0.2306
# Epoch 64/100
# 11/11 [==============================] - 2s 184ms/step - loss: 0.3904 - error_output_loss: 0.2603 - diff_output_loss: 0.1302 - error_output_accuracy: 0.7424 - diff_output_mae: 0.2747 - val_loss: 0.3399 - val_error_output_loss: 0.2635 - val_diff_output_loss: 0.0764 - val_error_output_accuracy: 0.7590 - val_diff_output_mae: 0.2221
# Epoch 65/100
# 11/11 [==============================] - 1s 134ms/step - loss: 0.3586 - error_output_loss: 0.2550 - diff_output_loss: 0.1037 - error_output_accuracy: 0.7818 - diff_output_mae: 0.2629 - val_loss: 0.3507 - val_error_output_loss: 0.2700 - val_diff_output_loss: 0.0807 - val_error_output_accuracy: 0.7470 - val_diff_output_mae: 0.2340
# Epoch 66/100
# 11/11 [==============================] - 1s 137ms/step - loss: 0.3502 - error_output_loss: 0.2433 - diff_output_loss: 0.1069 - error_output_accuracy: 0.7758 - diff_output_mae: 0.2559 - val_loss: 0.3827 - val_error_output_loss: 0.2807 - val_diff_output_loss: 0.1020 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2621
# Epoch 67/100
# 11/11 [==============================] - 1s 130ms/step - loss: 0.3454 - error_output_loss: 0.2423 - diff_output_loss: 0.1031 - error_output_accuracy: 0.7818 - diff_output_mae: 0.2528 - val_loss: 0.3764 - val_error_output_loss: 0.2883 - val_diff_output_loss: 0.0882 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2511
# Epoch 68/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.3428 - error_output_loss: 0.2352 - diff_output_loss: 0.1075 - error_output_accuracy: 0.7727 - diff_output_mae: 0.2624 - val_loss: 0.3767 - val_error_output_loss: 0.2965 - val_diff_output_loss: 0.0802 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2305
# Epoch 69/100
# 11/11 [==============================] - 2s 139ms/step - loss: 0.3458 - error_output_loss: 0.2307 - diff_output_loss: 0.1151 - error_output_accuracy: 0.7939 - diff_output_mae: 0.2705 - val_loss: 0.3938 - val_error_output_loss: 0.2987 - val_diff_output_loss: 0.0952 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2459
# Epoch 70/100
# 11/11 [==============================] - 2s 144ms/step - loss: 0.3361 - error_output_loss: 0.2213 - diff_output_loss: 0.1147 - error_output_accuracy: 0.7848 - diff_output_mae: 0.2730 - val_loss: 0.3781 - val_error_output_loss: 0.3040 - val_diff_output_loss: 0.0741 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2319
# Epoch 71/100
# 11/11 [==============================] - 1s 134ms/step - loss: 0.3126 - error_output_loss: 0.2244 - diff_output_loss: 0.0882 - error_output_accuracy: 0.7727 - diff_output_mae: 0.2344 - val_loss: 0.3735 - val_error_output_loss: 0.3024 - val_diff_output_loss: 0.0711 - val_error_output_accuracy: 0.7229 - val_diff_output_mae: 0.2288
# Epoch 72/100
# 11/11 [==============================] - 1s 136ms/step - loss: 0.3106 - error_output_loss: 0.2256 - diff_output_loss: 0.0850 - error_output_accuracy: 0.7727 - diff_output_mae: 0.2295 - val_loss: 0.3510 - val_error_output_loss: 0.2853 - val_diff_output_loss: 0.0657 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2142
# Epoch 73/100
# 11/11 [==============================] - 1s 131ms/step - loss: 0.3195 - error_output_loss: 0.2096 - diff_output_loss: 0.1099 - error_output_accuracy: 0.8000 - diff_output_mae: 0.2632 - val_loss: 0.3649 - val_error_output_loss: 0.2941 - val_diff_output_loss: 0.0708 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2238
# Epoch 74/100
# 11/11 [==============================] - 1s 130ms/step - loss: 0.3291 - error_output_loss: 0.2132 - diff_output_loss: 0.1158 - error_output_accuracy: 0.7970 - diff_output_mae: 0.2675 - val_loss: 0.3847 - val_error_output_loss: 0.2889 - val_diff_output_loss: 0.0958 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2552
# Epoch 75/100
# 11/11 [==============================] - 1s 138ms/step - loss: 0.3095 - error_output_loss: 0.2116 - diff_output_loss: 0.0980 - error_output_accuracy: 0.7970 - diff_output_mae: 0.2468 - val_loss: 0.3692 - val_error_output_loss: 0.2956 - val_diff_output_loss: 0.0736 - val_error_output_accuracy: 0.6988 - val_diff_output_mae: 0.2265
# Epoch 76/100
# 11/11 [==============================] - 2s 139ms/step - loss: 0.3074 - error_output_loss: 0.2134 - diff_output_loss: 0.0940 - error_output_accuracy: 0.7848 - diff_output_mae: 0.2387 - val_loss: 0.3702 - val_error_output_loss: 0.2962 - val_diff_output_loss: 0.0739 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2241
# Epoch 77/100
# 11/11 [==============================] - 2s 142ms/step - loss: 0.2956 - error_output_loss: 0.2061 - diff_output_loss: 0.0895 - error_output_accuracy: 0.8000 - diff_output_mae: 0.2395 - val_loss: 0.3608 - val_error_output_loss: 0.2894 - val_diff_output_loss: 0.0714 - val_error_output_accuracy: 0.7108 - val_diff_output_mae: 0.2151
# Epoch 78/100
# 11/11 [==============================] - 1s 137ms/step - loss: 0.2917 - error_output_loss: 0.1995 - diff_output_loss: 0.0922 - error_output_accuracy: 0.8030 - diff_output_mae: 0.2403 - val_loss: 0.3701 - val_error_output_loss: 0.3029 - val_diff_output_loss: 0.0672 - val_error_output_accuracy: 0.6867 - val_diff_output_mae: 0.2168
# Epoch 79/100
# 11/11 [==============================] - 2s 142ms/step - loss: 0.3002 - error_output_loss: 0.2044 - diff_output_loss: 0.0959 - error_output_accuracy: 0.8030 - diff_output_mae: 0.2402 - val_loss: 0.3853 - val_error_output_loss: 0.3080 - val_diff_output_loss: 0.0773 - val_error_output_accuracy: 0.6747 - val_diff_output_mae: 0.2328
# 3/3 [==============================] - 4s 22ms/step
# Validation Difficulty MAE: 0.22
# Model trained and saved!

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
tutor_loaded.model.summary()
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  embedding (Embedding)       (None, 8, 128)               3456      ['input_1[0][0]']
#
#  bidirectional (Bidirection  (None, 8, 1024)              2625536   ['embedding[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 8, 512)               2623488   ['bidirectional[0][0]']
#  onal)
#
#  global_max_pooling1d (Glob  (None, 512)                  0         ['bidirectional_1[0][0]']
#  alMaxPooling1D)
#
#  input_2 (InputLayer)        [(None, 6)]                  0         []
#
#  concatenate (Concatenate)   (None, 518)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense (Dense)               (None, 128)                  66432     ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  error_output (Dense)        (None, 5)                    645       ['dropout[0][0]']
#
#  diff_output (Dense)         (None, 1)                    129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5319686 (20.29 MB)
# Trainable params: 5319686 (20.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)

test_words = ['xylaphone', 'neese', 'psikology', 'nife', 'honnest']
results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_difficulty': 0})

for result in results:
    error_type = result['max_confidence_type']
    grouped_results[error_type]['count'] += 1
    grouped_results[error_type]['total_score_change'] += result['score_change']
    grouped_results[error_type]['words'].append(result['word'])
    grouped_results[error_type]['avg_difficulty'] += result['actual_difficulty']

print("\n=== Grouped Results ===")
for error_type, data in grouped_results.items():
    avg_diff = data['avg_difficulty'] / data['count'] if data['count'] > 0 else 0
    rounded_difficulty_level = round(avg_diff)
    print(f"Error Type: {error_type}")
    print(f"  Count: {data['count']}")
    print(f"  Total Score Change: {data['total_score_change']}")
    print(f"  Average Difficulty: {avg_diff:.2f}")
    print(f"  Words: {', '.join(data['words'])}")

    if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
        error_type_words = tutor_loaded.processor.df[
            (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
            (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
        ]

        if not error_type_words.empty:
            suggested_words = error_type_words['Incorrect_Word'].sample(min(5, len(error_type_words))).tolist()
            print(f"  Suggested Words:")
            for i, word in enumerate(suggested_words, 1):
                difficulty = tutor_loaded.processor.get_difficulty(word)
                print(f"    {i}. {word}")
        else:
            print("No suggested words available.")
    else:
        print("dataset not loaded correctly.")
# Out:
# Dataset rows without duplicate: 413
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 111
#   Letter-Phoneme Correspondence: 111
#   Omission of Letters: 40
#   Silent Letters: 69
#   Transpositions: 82
# 1/1 [==============================] - 4s 4s/step
#
# Word: xylaphone
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (81.96%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (81.96%)
# Predicted Difficulty: 2.91 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 35ms/step
#
# Word: neese
# Status: ✗ Incorrect
# Error Types: Unknown (29.68%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (29.68%)
# Predicted Difficulty: 2.48 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 32ms/step
#
# Word: psikology
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (67.77%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (67.77%)
# Predicted Difficulty: 4.01 | Actual Difficulty: 4
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 36ms/step
#
# Word: nife
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (45.62%), Omission of Letters (32.68%), Silent Letters (48.94%)
# Max Confidence Error Type: Silent Letters (48.94%)
# Predicted Difficulty: 2.19 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 43ms/step
#
# Word: honnest
# Status: ✗ Incorrect
# Error Types: Addition of Letters (92.34%)
# Max Confidence Error Type: Addition of Letters (92.34%)
# Predicted Difficulty: 2.92 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
#
# === Grouped Results ===
# Error Type: Letter-Phoneme Correspondence
#   Count: 3
#   Total Score Change: 0
#   Average Difficulty: 2.00
#   Words: xylaphone, neese, psikology
#   Suggested Words:
#     1. chawk
#     2. goast
#     3. ekkoe
#     4. klimb
#     5. foto
# Error Type: Silent Letters
#   Count: 1
#   Total Score Change: 0
#   Average Difficulty: 2.00
#   Words: nife
#   Suggested Words:
#     1. det
#     2. haf
#     3. rist
#     4. thum
#     5. naw
# Error Type: Addition of Letters
#   Count: 1
#   Total Score Change: 0
#   Average Difficulty: 3.00
#   Words: honnest
#   Suggested Words:
#     1. bananna
#     2. summerr
#     3. kneeldd
#     4. reesign
#     5. balleet

# %%
error_types = list(grouped_results.keys())
error_counts = [grouped_results[et]['count'] for et in error_types]

plt.figure(figsize=(10, 6))
plt.bar(error_types, error_counts, color='skyblue')

plt.xlabel('Error Types')
plt.ylabel('Count')
plt.title('Error Type Distribution')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
