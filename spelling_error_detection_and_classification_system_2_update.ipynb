# %%
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
from sklearn.metrics import confusion_matrix, classification_report, multilabel_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("TensorFlow version: ", tf.__version__)
# Out:
# Num GPUs Available:  0
# Num CPUs Available:  1
# TensorFlow version:  2.15.0

# %%
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 187        right           rite                 Silent Letters             5
# 484         case           caes                 Transpositions             4
# 392           go            goo            Addition of Letters             2
# 461     mountain        mountan            Omission of Letters             8
# 348       bright          brite  Letter-Phoneme Correspondence             6
# 122         face          facce            Addition of Letters             4
# 335     thursday       thurdsay                 Transpositions             8
# 210         talk            tak                 Silent Letters             4
# 224         book            bok            Omission of Letters             4
# 540        shell           shel            Omission of Letters             5
# 321       hasten          hasen                 Silent Letters             6
# 212       safari         safary  Letter-Phoneme Correspondence             6
# 506      prophet         profet  Letter-Phoneme Correspondence             7
# 592       writer           rite                 Silent Letters             5
# 251           he            hee            Addition of Letters             2
# 185       little          litle            Omission of Letters             6
# 522      station        stashun  Letter-Phoneme Correspondence             7
# 146       butter        buttter            Addition of Letters             6
# 397      brother       brotheer            Addition of Letters             7
# 419         rain           rane  Letter-Phoneme Correspondence             4
#
#      Difficulty_Level
# 187                 2
# 484                 1
# 392                 1
# 461                 4
# 348                 3
# 122                 2
# 335                 4
# 210                 2
# 224                 2
# 540                 2
# 321                 3
# 212                 3
# 506                 3
# 592                 2
# 251                 1
# 185                 3
# 522                 3
# 146                 3
# 397                 3
# 419                 2

# %%
class DataProcessor:
    def __init__(self, dataset_path):
        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)
        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())
        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))
        self._create_char_encoding()
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}
        self.max_difficulty = self.df['Difficulty_Level'].max()
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")

    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word
        
        edits = jellyfish.levenshtein_distance(word, correct_word)
        
        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)
        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)
        soundex_match = jellyfish.soundex(word) == jellyfish.soundex(correct_word)
        metaphone_match = jellyfish.metaphone(word) == jellyfish.metaphone(correct_word)
        nysiis_match = jellyfish.nysiis(word) == jellyfish.nysiis(correct_word)
        
        silent_letter_flag = False
        
        silent_letter_patterns = {
            'k': ['kn'], 'w': ['wr'], 'b': ['mb'], 'h': ['gh', 'rh', 'wh'],
            'l': ['lk', 'lm'], 'g': ['gn'], 'p': ['ps', 'pn'], 't': ['tch', 'tle'],
            'n': ['mn'], 'u': ['gu'], 'c': ['sc']
        }
        
        if omission_flag:
            for silent_letter, patterns in silent_letter_patterns.items():
                for pattern in patterns:
                    if any(pattern in correct_word and pattern not in word for pattern in patterns):
                        silent_letter_flag = True
                        break
        
        common_silent_combinations = [
            ('k', 'kn', 'n'),  
            ('g', 'gn', 'n'),  
            ('w', 'wr', 'r'),  
            ('p', 'ps', 's'),  
            ('b', 'mb', 'm'),  
            ('h', 'gh', 'g')   
        ]
        
        for silent_letter, full_pattern, shortened in common_silent_combinations:
            if shortened in word and full_pattern in correct_word:
                silent_letter_flag = True
                break
        
        if correct_word.endswith('e') and not word.endswith('e') and soundex_match:
            silent_letter_flag = True
        
        phoneme_mismatch_flag = not metaphone_match and not transposition_flag and not silent_letter_flag
        
        common_substitutions = [
            ('f', 'ph'), ('f', 'gh'), ('k', 'ch'), ('k', 'q'),
            ('s', 'c'), ('z', 's'), ('j', 'g'), ('ee', 'ea'),
            ('i', 'y'), ('ks', 'x'), ('shun', 'tion'), ('kw', 'qu')
        ]
        
        substitution_flag = False
        for sub_pair in common_substitutions:
            if (sub_pair[0] in word and sub_pair[1] in correct_word) or (sub_pair[1] in word and sub_pair[0] in correct_word):
                substitution_flag = True
                break
        
        doubled_letter_flag = False
        for i in range(len(word)-1):
            if word[i] == word[i+1]:
                if i+1 >= len(correct_word) or i >= len(correct_word) or word[i] != correct_word[i] or word[i+1] != correct_word[i+1]:
                    doubled_letter_flag = True
                    break
        
        vowels = 'aeiou'
        vowel_confusion = False
        word_vowels = [c for c in word if c in vowels]
        correct_vowels = [c for c in correct_word if c in vowels]
        if len(word_vowels) != len(correct_vowels) or ''.join(word_vowels) != ''.join(correct_vowels):
            vowel_confusion = True
        
        return np.array([
            edits,
            transposition_flag,
            omission_flag,
            addition_flag,
            phoneme_mismatch_flag,
            silent_letter_flag,
            substitution_flag,
            doubled_letter_flag,
            vowel_confusion,
            int(not soundex_match),
            int(not metaphone_match),
            int(not nysiis_match)
        ], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

# %%
class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("Dataset path must be provided")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("No dataset path provided")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(12,))
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(512, return_sequences=True, dropout=0.2))(x)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.2))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=15, restore_best_weights=True),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()},
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])

        error_preds_binary = (error_preds > 0.5).astype(int)

        print("\n ---Error Type Classification Report---")
        print(classification_report(
            self.y_val_error,
            error_preds_binary,
            target_names=self.processor.error_types,
            zero_division=0
        ))

        print("\n ---Confusion Matrices---")
        mcm = multilabel_confusion_matrix(self.y_val_error, error_preds_binary)

        plt.figure(figsize=(15, 10))
        for i, (matrix, error_type) in enumerate(zip(mcm, self.processor.error_types)):
            plt.subplot(3, 3, i+1)
            sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues',
                      xticklabels=['Predicted Negative', 'Predicted Positive'],
                      yticklabels=['Actual Negative', 'Actual Positive'])
            plt.title(f'Confusion Matrix for {error_type}')
        plt.tight_layout()
        plt.savefig('confusion_matrices.png')
        plt.show()

        print("\n ---Difficulty Prediction---")
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 8))

        plt.subplot(2, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(2, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.subplot(2, 2, 3)
        plt.plot(self.history.history['error_output_loss'], label='Error Classification Loss')
        plt.plot(self.history.history['val_error_output_loss'], label='Val Error Classification Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Error Classification Loss')
        plt.legend()

        plt.subplot(2, 2, 4)
        plt.plot(self.history.history['diff_output_loss'], label='Difficulty Prediction Loss')
        plt.plot(self.history.history['val_diff_output_loss'], label='Val Difficulty Prediction Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Difficulty Prediction Loss')
        plt.legend()

        plt.tight_layout()
        plt.savefig('training_history.png')
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
            confidences = {'Correct': 1.0}
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences,
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# Epoch 1/100
# 14/14 [==============================] - 24s 504ms/step - loss: 3.5062 - error_output_loss: 0.6677 - diff_output_loss: 2.8385 - error_output_accuracy: 0.1415 - diff_output_mae: 1.3680 - val_loss: 1.1531 - val_error_output_loss: 0.6114 - val_diff_output_loss: 0.5417 - val_error_output_accuracy: 0.1121 - val_diff_output_mae: 0.6283
# Epoch 2/100
# 14/14 [==============================] - 3s 237ms/step - loss: 0.9993 - error_output_loss: 0.5735 - diff_output_loss: 0.4258 - error_output_accuracy: 0.1816 - diff_output_mae: 0.5215 - val_loss: 0.8480 - val_error_output_loss: 0.5390 - val_diff_output_loss: 0.3089 - val_error_output_accuracy: 0.2336 - val_diff_output_mae: 0.4370
# Epoch 3/100
# 14/14 [==============================] - 2s 176ms/step - loss: 0.8382 - error_output_loss: 0.5244 - diff_output_loss: 0.3138 - error_output_accuracy: 0.2005 - diff_output_mae: 0.4503 - val_loss: 0.7175 - val_error_output_loss: 0.5057 - val_diff_output_loss: 0.2118 - val_error_output_accuracy: 0.2336 - val_diff_output_mae: 0.3613
# Epoch 4/100
# 14/14 [==============================] - 2s 148ms/step - loss: 0.7919 - error_output_loss: 0.5072 - diff_output_loss: 0.2847 - error_output_accuracy: 0.2217 - diff_output_mae: 0.4313 - val_loss: 0.7286 - val_error_output_loss: 0.4983 - val_diff_output_loss: 0.2303 - val_error_output_accuracy: 0.2523 - val_diff_output_mae: 0.3792
# Epoch 5/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.7362 - error_output_loss: 0.4957 - diff_output_loss: 0.2405 - error_output_accuracy: 0.3443 - diff_output_mae: 0.4023 - val_loss: 0.6932 - val_error_output_loss: 0.4857 - val_diff_output_loss: 0.2076 - val_error_output_accuracy: 0.5234 - val_diff_output_mae: 0.3637
# Epoch 6/100
# 14/14 [==============================] - 2s 165ms/step - loss: 0.7043 - error_output_loss: 0.4873 - diff_output_loss: 0.2170 - error_output_accuracy: 0.3986 - diff_output_mae: 0.3704 - val_loss: 0.6523 - val_error_output_loss: 0.4748 - val_diff_output_loss: 0.1775 - val_error_output_accuracy: 0.5981 - val_diff_output_mae: 0.3278
# Epoch 7/100
# 14/14 [==============================] - 2s 171ms/step - loss: 0.6751 - error_output_loss: 0.4733 - diff_output_loss: 0.2018 - error_output_accuracy: 0.4858 - diff_output_mae: 0.3622 - val_loss: 0.6269 - val_error_output_loss: 0.4645 - val_diff_output_loss: 0.1624 - val_error_output_accuracy: 0.6075 - val_diff_output_mae: 0.3143
# Epoch 8/100
# 14/14 [==============================] - 3s 222ms/step - loss: 0.6630 - error_output_loss: 0.4615 - diff_output_loss: 0.2015 - error_output_accuracy: 0.5472 - diff_output_mae: 0.3545 - val_loss: 0.6143 - val_error_output_loss: 0.4533 - val_diff_output_loss: 0.1610 - val_error_output_accuracy: 0.6262 - val_diff_output_mae: 0.3186
# Epoch 9/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.6517 - error_output_loss: 0.4489 - diff_output_loss: 0.2028 - error_output_accuracy: 0.5849 - diff_output_mae: 0.3576 - val_loss: 0.5991 - val_error_output_loss: 0.4377 - val_diff_output_loss: 0.1614 - val_error_output_accuracy: 0.6729 - val_diff_output_mae: 0.3215
# Epoch 10/100
# 14/14 [==============================] - 2s 176ms/step - loss: 0.6266 - error_output_loss: 0.4345 - diff_output_loss: 0.1921 - error_output_accuracy: 0.6179 - diff_output_mae: 0.3453 - val_loss: 0.5769 - val_error_output_loss: 0.4243 - val_diff_output_loss: 0.1526 - val_error_output_accuracy: 0.6542 - val_diff_output_mae: 0.3041
# Epoch 11/100
# 14/14 [==============================] - 2s 177ms/step - loss: 0.5997 - error_output_loss: 0.4211 - diff_output_loss: 0.1786 - error_output_accuracy: 0.6368 - diff_output_mae: 0.3274 - val_loss: 0.5530 - val_error_output_loss: 0.4113 - val_diff_output_loss: 0.1417 - val_error_output_accuracy: 0.6916 - val_diff_output_mae: 0.2947
# Epoch 12/100
# 14/14 [==============================] - 3s 201ms/step - loss: 0.5899 - error_output_loss: 0.4092 - diff_output_loss: 0.1807 - error_output_accuracy: 0.7288 - diff_output_mae: 0.3281 - val_loss: 0.5438 - val_error_output_loss: 0.3984 - val_diff_output_loss: 0.1454 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2982
# Epoch 13/100
# 14/14 [==============================] - 3s 192ms/step - loss: 0.5583 - error_output_loss: 0.3900 - diff_output_loss: 0.1683 - error_output_accuracy: 0.7618 - diff_output_mae: 0.3089 - val_loss: 0.5187 - val_error_output_loss: 0.3837 - val_diff_output_loss: 0.1350 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.2929
# Epoch 14/100
# 14/14 [==============================] - 3s 190ms/step - loss: 0.5506 - error_output_loss: 0.3785 - diff_output_loss: 0.1720 - error_output_accuracy: 0.7618 - diff_output_mae: 0.3249 - val_loss: 0.5091 - val_error_output_loss: 0.3697 - val_diff_output_loss: 0.1393 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2991
# Epoch 15/100
# 14/14 [==============================] - 2s 172ms/step - loss: 0.5375 - error_output_loss: 0.3680 - diff_output_loss: 0.1695 - error_output_accuracy: 0.7642 - diff_output_mae: 0.3221 - val_loss: 0.4958 - val_error_output_loss: 0.3594 - val_diff_output_loss: 0.1363 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3001
# Epoch 16/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.5060 - error_output_loss: 0.3519 - diff_output_loss: 0.1541 - error_output_accuracy: 0.8019 - diff_output_mae: 0.3096 - val_loss: 0.5308 - val_error_output_loss: 0.3455 - val_diff_output_loss: 0.1853 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.3286
# Epoch 17/100
# 14/14 [==============================] - 2s 182ms/step - loss: 0.5263 - error_output_loss: 0.3463 - diff_output_loss: 0.1800 - error_output_accuracy: 0.7712 - diff_output_mae: 0.3260 - val_loss: 0.4871 - val_error_output_loss: 0.3321 - val_diff_output_loss: 0.1550 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3179
# Epoch 18/100
# 14/14 [==============================] - 3s 187ms/step - loss: 0.5199 - error_output_loss: 0.3287 - diff_output_loss: 0.1912 - error_output_accuracy: 0.8160 - diff_output_mae: 0.3387 - val_loss: 0.4676 - val_error_output_loss: 0.3219 - val_diff_output_loss: 0.1457 - val_error_output_accuracy: 0.8972 - val_diff_output_mae: 0.3084
# Epoch 19/100
# 14/14 [==============================] - 2s 172ms/step - loss: 0.5301 - error_output_loss: 0.3166 - diff_output_loss: 0.2135 - error_output_accuracy: 0.8443 - diff_output_mae: 0.3549 - val_loss: 0.4593 - val_error_output_loss: 0.3103 - val_diff_output_loss: 0.1490 - val_error_output_accuracy: 0.8972 - val_diff_output_mae: 0.3071
# Epoch 20/100
# 14/14 [==============================] - 2s 140ms/step - loss: 0.5031 - error_output_loss: 0.3044 - diff_output_loss: 0.1987 - error_output_accuracy: 0.8656 - diff_output_mae: 0.3404 - val_loss: 0.5644 - val_error_output_loss: 0.3016 - val_diff_output_loss: 0.2627 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.4071
# Epoch 21/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.4880 - error_output_loss: 0.2975 - diff_output_loss: 0.1905 - error_output_accuracy: 0.8844 - diff_output_mae: 0.3431 - val_loss: 0.4706 - val_error_output_loss: 0.2890 - val_diff_output_loss: 0.1817 - val_error_output_accuracy: 0.9252 - val_diff_output_mae: 0.3458
# Epoch 22/100
# 14/14 [==============================] - 2s 171ms/step - loss: 0.4309 - error_output_loss: 0.2827 - diff_output_loss: 0.1482 - error_output_accuracy: 0.8632 - diff_output_mae: 0.2956 - val_loss: 0.4201 - val_error_output_loss: 0.2778 - val_diff_output_loss: 0.1423 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.3049
# Epoch 23/100
# 14/14 [==============================] - 2s 183ms/step - loss: 0.4210 - error_output_loss: 0.2772 - diff_output_loss: 0.1438 - error_output_accuracy: 0.8679 - diff_output_mae: 0.2886 - val_loss: 0.4111 - val_error_output_loss: 0.2719 - val_diff_output_loss: 0.1392 - val_error_output_accuracy: 0.9252 - val_diff_output_mae: 0.3009
# Epoch 24/100
# 14/14 [==============================] - 2s 164ms/step - loss: 0.4103 - error_output_loss: 0.2624 - diff_output_loss: 0.1480 - error_output_accuracy: 0.8726 - diff_output_mae: 0.3005 - val_loss: 0.4012 - val_error_output_loss: 0.2588 - val_diff_output_loss: 0.1424 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.3042
# Epoch 25/100
# 14/14 [==============================] - 3s 189ms/step - loss: 0.4217 - error_output_loss: 0.2613 - diff_output_loss: 0.1603 - error_output_accuracy: 0.8538 - diff_output_mae: 0.3115 - val_loss: 0.3961 - val_error_output_loss: 0.2508 - val_diff_output_loss: 0.1453 - val_error_output_accuracy: 0.8972 - val_diff_output_mae: 0.3076
# Epoch 26/100
# 14/14 [==============================] - 2s 152ms/step - loss: 0.3925 - error_output_loss: 0.2488 - diff_output_loss: 0.1437 - error_output_accuracy: 0.8726 - diff_output_mae: 0.2981 - val_loss: 0.3978 - val_error_output_loss: 0.2471 - val_diff_output_loss: 0.1507 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.2995
# Epoch 27/100
# 14/14 [==============================] - 2s 168ms/step - loss: 0.3796 - error_output_loss: 0.2421 - diff_output_loss: 0.1375 - error_output_accuracy: 0.8679 - diff_output_mae: 0.2800 - val_loss: 0.3957 - val_error_output_loss: 0.2367 - val_diff_output_loss: 0.1590 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3079
# Epoch 28/100
# 14/14 [==============================] - 3s 196ms/step - loss: 0.3733 - error_output_loss: 0.2291 - diff_output_loss: 0.1442 - error_output_accuracy: 0.8821 - diff_output_mae: 0.2928 - val_loss: 0.3869 - val_error_output_loss: 0.2312 - val_diff_output_loss: 0.1557 - val_error_output_accuracy: 0.8972 - val_diff_output_mae: 0.3147
# Epoch 29/100
# 14/14 [==============================] - 3s 195ms/step - loss: 0.3446 - error_output_loss: 0.2221 - diff_output_loss: 0.1225 - error_output_accuracy: 0.8892 - diff_output_mae: 0.2769 - val_loss: 0.3621 - val_error_output_loss: 0.2244 - val_diff_output_loss: 0.1376 - val_error_output_accuracy: 0.9065 - val_diff_output_mae: 0.2945
# Epoch 30/100
# 14/14 [==============================] - 3s 209ms/step - loss: 0.3604 - error_output_loss: 0.2142 - diff_output_loss: 0.1462 - error_output_accuracy: 0.8868 - diff_output_mae: 0.2950 - val_loss: 0.3730 - val_error_output_loss: 0.2174 - val_diff_output_loss: 0.1556 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3104
# Epoch 31/100
# 14/14 [==============================] - 3s 212ms/step - loss: 0.3443 - error_output_loss: 0.2076 - diff_output_loss: 0.1368 - error_output_accuracy: 0.8915 - diff_output_mae: 0.2870 - val_loss: 0.3613 - val_error_output_loss: 0.2121 - val_diff_output_loss: 0.1491 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3092
# Epoch 32/100
# 14/14 [==============================] - 3s 253ms/step - loss: 0.3388 - error_output_loss: 0.2026 - diff_output_loss: 0.1362 - error_output_accuracy: 0.8821 - diff_output_mae: 0.2889 - val_loss: 0.3421 - val_error_output_loss: 0.2079 - val_diff_output_loss: 0.1342 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3027
# Epoch 33/100
# 14/14 [==============================] - 2s 171ms/step - loss: 0.3333 - error_output_loss: 0.2038 - diff_output_loss: 0.1295 - error_output_accuracy: 0.8797 - diff_output_mae: 0.2844 - val_loss: 0.3756 - val_error_output_loss: 0.2008 - val_diff_output_loss: 0.1748 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3185
# Epoch 34/100
# 14/14 [==============================] - 3s 240ms/step - loss: 0.3476 - error_output_loss: 0.1908 - diff_output_loss: 0.1568 - error_output_accuracy: 0.8892 - diff_output_mae: 0.3132 - val_loss: 0.3241 - val_error_output_loss: 0.1978 - val_diff_output_loss: 0.1263 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2928
# Epoch 35/100
# 14/14 [==============================] - 2s 166ms/step - loss: 0.3665 - error_output_loss: 0.1865 - diff_output_loss: 0.1800 - error_output_accuracy: 0.8868 - diff_output_mae: 0.3243 - val_loss: 0.4341 - val_error_output_loss: 0.1946 - val_diff_output_loss: 0.2395 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3778
# Epoch 36/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.3370 - error_output_loss: 0.1787 - diff_output_loss: 0.1582 - error_output_accuracy: 0.8892 - diff_output_mae: 0.3123 - val_loss: 0.3391 - val_error_output_loss: 0.1920 - val_diff_output_loss: 0.1472 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3031
# Epoch 37/100
# 14/14 [==============================] - 2s 173ms/step - loss: 0.3214 - error_output_loss: 0.1720 - diff_output_loss: 0.1494 - error_output_accuracy: 0.9033 - diff_output_mae: 0.2934 - val_loss: 0.3334 - val_error_output_loss: 0.1862 - val_diff_output_loss: 0.1473 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3142
# Epoch 38/100
# 14/14 [==============================] - 3s 193ms/step - loss: 0.3172 - error_output_loss: 0.1669 - diff_output_loss: 0.1504 - error_output_accuracy: 0.9080 - diff_output_mae: 0.3054 - val_loss: 0.3208 - val_error_output_loss: 0.1820 - val_diff_output_loss: 0.1388 - val_error_output_accuracy: 0.8879 - val_diff_output_mae: 0.3038
# Epoch 39/100
# 14/14 [==============================] - 2s 181ms/step - loss: 0.2897 - error_output_loss: 0.1589 - diff_output_loss: 0.1308 - error_output_accuracy: 0.9104 - diff_output_mae: 0.2799 - val_loss: 0.3061 - val_error_output_loss: 0.1786 - val_diff_output_loss: 0.1275 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.2899
# Epoch 40/100
# 14/14 [==============================] - 2s 176ms/step - loss: 0.2625 - error_output_loss: 0.1534 - diff_output_loss: 0.1091 - error_output_accuracy: 0.9127 - diff_output_mae: 0.2535 - val_loss: 0.3049 - val_error_output_loss: 0.1758 - val_diff_output_loss: 0.1291 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.2935
# Epoch 41/100
# 14/14 [==============================] - 2s 158ms/step - loss: 0.2602 - error_output_loss: 0.1455 - diff_output_loss: 0.1147 - error_output_accuracy: 0.9151 - diff_output_mae: 0.2634 - val_loss: 0.3130 - val_error_output_loss: 0.1684 - val_diff_output_loss: 0.1446 - val_error_output_accuracy: 0.8785 - val_diff_output_mae: 0.3150
# Epoch 42/100
# 14/14 [==============================] - 3s 194ms/step - loss: 0.2705 - error_output_loss: 0.1390 - diff_output_loss: 0.1315 - error_output_accuracy: 0.9316 - diff_output_mae: 0.2773 - val_loss: 0.2931 - val_error_output_loss: 0.1658 - val_diff_output_loss: 0.1273 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.2889
# Epoch 43/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.2702 - error_output_loss: 0.1403 - diff_output_loss: 0.1299 - error_output_accuracy: 0.9104 - diff_output_mae: 0.2854 - val_loss: 0.3264 - val_error_output_loss: 0.1718 - val_diff_output_loss: 0.1545 - val_error_output_accuracy: 0.8692 - val_diff_output_mae: 0.3165
# Epoch 44/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.2621 - error_output_loss: 0.1303 - diff_output_loss: 0.1318 - error_output_accuracy: 0.9245 - diff_output_mae: 0.2804 - val_loss: 0.3125 - val_error_output_loss: 0.1684 - val_diff_output_loss: 0.1441 - val_error_output_accuracy: 0.8598 - val_diff_output_mae: 0.3033
# Epoch 45/100
# 14/14 [==============================] - 2s 135ms/step - loss: 0.2524 - error_output_loss: 0.1267 - diff_output_loss: 0.1257 - error_output_accuracy: 0.9269 - diff_output_mae: 0.2707 - val_loss: 0.3223 - val_error_output_loss: 0.1718 - val_diff_output_loss: 0.1505 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3085
# Epoch 46/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.2398 - error_output_loss: 0.1279 - diff_output_loss: 0.1118 - error_output_accuracy: 0.9104 - diff_output_mae: 0.2609 - val_loss: 0.3076 - val_error_output_loss: 0.1712 - val_diff_output_loss: 0.1364 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.2913
# Epoch 47/100
# 14/14 [==============================] - 2s 158ms/step - loss: 0.2307 - error_output_loss: 0.1228 - diff_output_loss: 0.1079 - error_output_accuracy: 0.9222 - diff_output_mae: 0.2578 - val_loss: 0.3085 - val_error_output_loss: 0.1670 - val_diff_output_loss: 0.1414 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3028
# Epoch 48/100
# 14/14 [==============================] - 2s 145ms/step - loss: 0.2309 - error_output_loss: 0.1180 - diff_output_loss: 0.1129 - error_output_accuracy: 0.9340 - diff_output_mae: 0.2611 - val_loss: 0.3069 - val_error_output_loss: 0.1648 - val_diff_output_loss: 0.1421 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2913
# Epoch 49/100
# 14/14 [==============================] - 2s 135ms/step - loss: 0.2448 - error_output_loss: 0.1145 - diff_output_loss: 0.1304 - error_output_accuracy: 0.9387 - diff_output_mae: 0.2746 - val_loss: 0.3448 - val_error_output_loss: 0.1674 - val_diff_output_loss: 0.1774 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3357
# Epoch 50/100
# 14/14 [==============================] - 2s 139ms/step - loss: 0.2458 - error_output_loss: 0.1170 - diff_output_loss: 0.1288 - error_output_accuracy: 0.9269 - diff_output_mae: 0.2747 - val_loss: 0.3002 - val_error_output_loss: 0.1689 - val_diff_output_loss: 0.1313 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.2948
# Epoch 51/100
# 14/14 [==============================] - 2s 167ms/step - loss: 0.2339 - error_output_loss: 0.1100 - diff_output_loss: 0.1239 - error_output_accuracy: 0.9410 - diff_output_mae: 0.2724 - val_loss: 0.3198 - val_error_output_loss: 0.1607 - val_diff_output_loss: 0.1591 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3235
# Epoch 52/100
# 14/14 [==============================] - 2s 154ms/step - loss: 0.2140 - error_output_loss: 0.0999 - diff_output_loss: 0.1141 - error_output_accuracy: 0.9481 - diff_output_mae: 0.2669 - val_loss: 0.3100 - val_error_output_loss: 0.1625 - val_diff_output_loss: 0.1475 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3087
# Epoch 53/100
# 14/14 [==============================] - 2s 139ms/step - loss: 0.1973 - error_output_loss: 0.1076 - diff_output_loss: 0.0897 - error_output_accuracy: 0.9434 - diff_output_mae: 0.2285 - val_loss: 0.3012 - val_error_output_loss: 0.1560 - val_diff_output_loss: 0.1451 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3113
# Epoch 54/100
# 14/14 [==============================] - 2s 141ms/step - loss: 0.2001 - error_output_loss: 0.0953 - diff_output_loss: 0.1048 - error_output_accuracy: 0.9481 - diff_output_mae: 0.2524 - val_loss: 0.3011 - val_error_output_loss: 0.1690 - val_diff_output_loss: 0.1320 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3029
# Epoch 55/100
# 14/14 [==============================] - 2s 176ms/step - loss: 0.1873 - error_output_loss: 0.1002 - diff_output_loss: 0.0871 - error_output_accuracy: 0.9292 - diff_output_mae: 0.2247 - val_loss: 0.2869 - val_error_output_loss: 0.1423 - val_diff_output_loss: 0.1447 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3057
# Epoch 56/100
# 14/14 [==============================] - 3s 200ms/step - loss: 0.2141 - error_output_loss: 0.1022 - diff_output_loss: 0.1119 - error_output_accuracy: 0.9363 - diff_output_mae: 0.2631 - val_loss: 0.2794 - val_error_output_loss: 0.1526 - val_diff_output_loss: 0.1268 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.2900
# Epoch 57/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.2123 - error_output_loss: 0.1014 - diff_output_loss: 0.1109 - error_output_accuracy: 0.9292 - diff_output_mae: 0.2573 - val_loss: 0.2816 - val_error_output_loss: 0.1423 - val_diff_output_loss: 0.1393 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3048
# Epoch 58/100
# 14/14 [==============================] - 2s 133ms/step - loss: 0.1944 - error_output_loss: 0.0901 - diff_output_loss: 0.1043 - error_output_accuracy: 0.9623 - diff_output_mae: 0.2496 - val_loss: 0.3033 - val_error_output_loss: 0.1528 - val_diff_output_loss: 0.1505 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3220
# Epoch 59/100
# 14/14 [==============================] - 2s 144ms/step - loss: 0.1978 - error_output_loss: 0.0874 - diff_output_loss: 0.1104 - error_output_accuracy: 0.9528 - diff_output_mae: 0.2631 - val_loss: 0.3102 - val_error_output_loss: 0.1512 - val_diff_output_loss: 0.1590 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3233
# Epoch 60/100
# 14/14 [==============================] - 2s 152ms/step - loss: 0.1954 - error_output_loss: 0.0874 - diff_output_loss: 0.1080 - error_output_accuracy: 0.9575 - diff_output_mae: 0.2473 - val_loss: 0.3150 - val_error_output_loss: 0.1603 - val_diff_output_loss: 0.1547 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3262
# Epoch 61/100
# 14/14 [==============================] - 2s 172ms/step - loss: 0.1885 - error_output_loss: 0.0899 - diff_output_loss: 0.0986 - error_output_accuracy: 0.9481 - diff_output_mae: 0.2401 - val_loss: 0.2946 - val_error_output_loss: 0.1492 - val_diff_output_loss: 0.1454 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.3141
# Epoch 62/100
# 14/14 [==============================] - 2s 166ms/step - loss: 0.1776 - error_output_loss: 0.0885 - diff_output_loss: 0.0891 - error_output_accuracy: 0.9410 - diff_output_mae: 0.2383 - val_loss: 0.3143 - val_error_output_loss: 0.1421 - val_diff_output_loss: 0.1722 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.3291
# Epoch 63/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.1871 - error_output_loss: 0.0809 - diff_output_loss: 0.1062 - error_output_accuracy: 0.9599 - diff_output_mae: 0.2543 - val_loss: 0.2861 - val_error_output_loss: 0.1427 - val_diff_output_loss: 0.1434 - val_error_output_accuracy: 0.8411 - val_diff_output_mae: 0.3058
# Epoch 64/100
# 14/14 [==============================] - 2s 151ms/step - loss: 0.1653 - error_output_loss: 0.0787 - diff_output_loss: 0.0866 - error_output_accuracy: 0.9623 - diff_output_mae: 0.2340 - val_loss: 0.3004 - val_error_output_loss: 0.1554 - val_diff_output_loss: 0.1450 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3098
# Epoch 65/100
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1739 - error_output_loss: 0.0788 - diff_output_loss: 0.0951 - error_output_accuracy: 0.9693 - diff_output_mae: 0.2403 - val_loss: 0.2860 - val_error_output_loss: 0.1488 - val_diff_output_loss: 0.1372 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.3067
# Epoch 66/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.1575 - error_output_loss: 0.0788 - diff_output_loss: 0.0787 - error_output_accuracy: 0.9599 - diff_output_mae: 0.2256 - val_loss: 0.3015 - val_error_output_loss: 0.1653 - val_diff_output_loss: 0.1362 - val_error_output_accuracy: 0.8318 - val_diff_output_mae: 0.2976
# Epoch 67/100
# 14/14 [==============================] - 2s 159ms/step - loss: 0.1616 - error_output_loss: 0.0733 - diff_output_loss: 0.0883 - error_output_accuracy: 0.9528 - diff_output_mae: 0.2324 - val_loss: 0.3085 - val_error_output_loss: 0.1564 - val_diff_output_loss: 0.1521 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3143
# Epoch 68/100
# 14/14 [==============================] - 2s 163ms/step - loss: 0.1584 - error_output_loss: 0.0687 - diff_output_loss: 0.0897 - error_output_accuracy: 0.9623 - diff_output_mae: 0.2355 - val_loss: 0.3302 - val_error_output_loss: 0.1527 - val_diff_output_loss: 0.1775 - val_error_output_accuracy: 0.8131 - val_diff_output_mae: 0.3379
# Epoch 69/100
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1761 - error_output_loss: 0.0751 - diff_output_loss: 0.1009 - error_output_accuracy: 0.9552 - diff_output_mae: 0.2440 - val_loss: 0.3024 - val_error_output_loss: 0.1636 - val_diff_output_loss: 0.1388 - val_error_output_accuracy: 0.8037 - val_diff_output_mae: 0.3066
# Epoch 70/100
# 14/14 [==============================] - 2s 153ms/step - loss: 0.1592 - error_output_loss: 0.0702 - diff_output_loss: 0.0889 - error_output_accuracy: 0.9599 - diff_output_mae: 0.2279 - val_loss: 0.2892 - val_error_output_loss: 0.1422 - val_diff_output_loss: 0.1470 - val_error_output_accuracy: 0.8505 - val_diff_output_mae: 0.3021
# Epoch 71/100
# 14/14 [==============================] - 2s 149ms/step - loss: 0.1567 - error_output_loss: 0.0664 - diff_output_loss: 0.0903 - error_output_accuracy: 0.9623 - diff_output_mae: 0.2343 - val_loss: 0.3097 - val_error_output_loss: 0.1697 - val_diff_output_loss: 0.1400 - val_error_output_accuracy: 0.8224 - val_diff_output_mae: 0.3023
# 4/4 [==============================] - 5s 54ms/step
#
#  ---Error Type Classification Report---
#                                precision    recall  f1-score   support
#
#           Addition of Letters       1.00      0.96      0.98        23
# Letter-Phoneme Correspondence       0.52      0.69      0.59        16
#           Omission of Letters       1.00      0.91      0.95        22
#                Silent Letters       0.84      0.76      0.80        21
#                Transpositions       1.00      0.80      0.89        25
#
#                     micro avg       0.87      0.83      0.85       107
#                     macro avg       0.87      0.82      0.84       107
#                  weighted avg       0.90      0.83      0.86       107
#                   samples avg       0.82      0.83      0.83       107
#
#
#  ---Confusion Matrices---
#  ---Difficulty Prediction---
# Validation Difficulty MAE: 0.29
# Model trained and saved!

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
tutor_loaded.model.summary()
# Out:
# Dataset rows without duplicate: 531
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 104
#   Omission of Letters: 107
#   Silent Letters: 106
#   Transpositions: 106
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  embedding (Embedding)       (None, 8, 128)               3712      ['input_1[0][0]']
#
#  bidirectional (Bidirection  (None, 8, 1024)              2625536   ['embedding[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 8, 512)               2623488   ['bidirectional[0][0]']
#  onal)
#
#  global_max_pooling1d (Glob  (None, 512)                  0         ['bidirectional_1[0][0]']
#  alMaxPooling1D)
#
#  input_2 (InputLayer)        [(None, 12)]                 0         []
#
#  concatenate (Concatenate)   (None, 524)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense (Dense)               (None, 128)                  67200     ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  error_output (Dense)        (None, 5)                    645       ['dropout[0][0]']
#
#  diff_output (Dense)         (None, 1)                    129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 5320710 (20.30 MB)
# Trainable params: 5320710 (20.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
test_words = [
    'nife',
    'rite',
    'mountan',
    'naw',
    'freind',
    'fone',
    'sykology',
    'aline',
    'safary',
    'kitcehn'
]

results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_confidence': 0.0, 'total_difficulty': 0.0})

for result in results:
    if not result['correct']:
        error_type = result['max_confidence_type']
        grouped_results[error_type]['count'] += 1
        grouped_results[error_type]['total_score_change'] += result['score_change']
        grouped_results[error_type]['words'].append(result['word'])
        grouped_results[error_type]['avg_confidence'] += result['confidence']
        grouped_results[error_type]['total_difficulty'] += result['predicted_difficulty']

print("\n=== Results Analysis by Error Type ===")
for error_type, data in grouped_results.items():
    if data['count'] > 0:
        data['avg_confidence'] /= data['count']
        data['avg_difficulty'] = data['total_difficulty'] / data['count']
        rounded_difficulty_level = round(data['avg_difficulty'])

        print(f"Error Type: {error_type}")
        print(f"  Count: {data['count']}")
        print(f"  Average Confidence: {data['avg_confidence']:.2%}")
        print(f"  Average Difficulty: {data['avg_difficulty']:.2f}")
        print(f"  Words: {', '.join(data['words'])}")

        if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
            error_type_words = tutor_loaded.processor.df[
                (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
                (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
            ]

            if not error_type_words.empty:
                new_words = error_type_words[~error_type_words['Incorrect_Word'].isin(data['words'])]

                if not new_words.empty:
                    suggested_words = new_words['Incorrect_Word'].sample(min(5, len(new_words))).tolist()
                    print(f"  Suggested Words (Difficulty {rounded_difficulty_level}):")
                    for i, word in enumerate(suggested_words, 1):
                        difficulty = tutor_loaded.processor.get_difficulty(word)
                        correct_word = error_type_words[error_type_words['Incorrect_Word'] == word]['Correct_Word'].iloc[0]
                        print(f"    {i}. {word} (correct: {correct_word})")


if grouped_results:
    error_types = list(grouped_results.keys())
    error_counts = [grouped_results[et]['count'] for et in error_types]
    avg_confidences = [grouped_results[et]['avg_confidence'] for et in error_types]

    fig, ax1 = plt.subplots(figsize=(12, 6))

    x = np.arange(len(error_types))
    bars = ax1.bar(x, error_counts, width=0.6, color='skyblue', label='Count')
    ax1.set_xlabel('Error Types')
    ax1.set_ylabel('Count')
    ax1.set_title('Error Type Distribution with Confidence')
    ax1.set_xticks(x)
    ax1.set_xticklabels(error_types, rotation=45, ha='right')

    ax2 = ax1.twinx()
    ax2.plot(x, avg_confidences, 'ro-', label='Confidence')
    ax2.set_ylabel('Average Confidence')
    ax2.set_ylim([0, 1])

    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper left')

    plt.tight_layout()
    plt.savefig('error_analysis.png')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
#
# Word: nife
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (61.97%), Silent Letters (69.32%)
# Max Confidence Error Type: Silent Letters (69.32%)
# Predicted Difficulty: 2.43 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 36ms/step
#
# Word: rite
# Status: ✗ Incorrect
# Error Types: Silent Letters (90.47%)
# Max Confidence Error Type: Silent Letters (90.47%)
# Predicted Difficulty: 2.23 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: mountan
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (33.10%), Omission of Letters (61.30%)
# Max Confidence Error Type: Omission of Letters (61.30%)
# Predicted Difficulty: 3.96 | Actual Difficulty: 4
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 28ms/step
#
# Word: naw
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (62.95%), Silent Letters (66.47%)
# Max Confidence Error Type: Silent Letters (66.47%)
# Predicted Difficulty: 1.92 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 28ms/step
#
# Word: freind
# Status: ✗ Incorrect
# Error Types: Transpositions (80.12%)
# Max Confidence Error Type: Transpositions (80.12%)
# Predicted Difficulty: 2.63 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: fone
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (86.32%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (86.32%)
# Predicted Difficulty: 2.5 | Actual Difficulty: 2
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: sykology
# Status: ✗ Incorrect
# Error Types: Unknown (27.79%)
# Max Confidence Error Type: Omission of Letters (27.79%)
# Predicted Difficulty: 3.38 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: aline
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (58.52%), Silent Letters (40.61%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (58.52%)
# Predicted Difficulty: 2.35 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: safary
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (97.98%)
# Max Confidence Error Type: Letter-Phoneme Correspondence (97.98%)
# Predicted Difficulty: 3.31 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 30ms/step
#
# Word: kitcehn
# Status: ✗ Incorrect
# Error Types: Letter-Phoneme Correspondence (35.31%), Transpositions (82.55%)
# Max Confidence Error Type: Transpositions (82.55%)
# Predicted Difficulty: 3.02 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
#
# === Results Analysis by Error Type ===
# Error Type: Silent Letters
#   Count: 3
#   Average Confidence: 75.42%
#   Average Difficulty: 2.19
#   Words: nife, rite, naw
#   Suggested Words (Difficulty 2):
#     1. tom (correct: tomb)
#     2. com (correct: comb)
#     3. wistle (correct: whistle)
#     4. rap (correct: wrap)
#     5. not (correct: knot)
# Error Type: Omission of Letters
#   Count: 2
#   Average Confidence: 44.54%
#   Average Difficulty: 3.67
#   Words: mountan, sykology
#   Suggested Words (Difficulty 4):
#     1. bathrom (correct: bathroom)
#     2. schol (correct: school)
#     3. begining (correct: beginning)
#     4. tomorow (correct: tomorrow)
#     5. wining (correct: winning)
# Error Type: Transpositions
#   Count: 2
#   Average Confidence: 81.33%
#   Average Difficulty: 2.83
#   Words: freind, kitcehn
#   Suggested Words (Difficulty 3):
#     1. yelolow (correct: yellow)
#     2. blankter (correct: blanket)
#     3. scohol (correct: school)
#     4. stuednt (correct: student)
#     5. bicylce (correct: bicycle)
# Error Type: Letter-Phoneme Correspondence
#   Count: 3
#   Average Confidence: 80.94%
#   Average Difficulty: 2.72
#   Words: fone, aline, safary
#   Suggested Words (Difficulty 3):
#     1. brite (correct: bright)
#     2. moshun (correct: motion)
#     3. dolfin (correct: dolphin)
#     4. fiziks (correct: physics)
#     5. bouns (correct: bounce)
